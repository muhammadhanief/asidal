# %%
# !pip install holoviews
# Out:
# Requirement already satisfied: holoviews in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (1.17.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from holoviews) (1.5.0)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from holoviews) (2.0.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from holoviews) (3.0.0)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from holoviews) (21.3)
# Requirement already satisfied: numpy>=1.0 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from holoviews) (1.23.2)
# Requirement already satisfied: colorcet in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from holoviews) (3.0.1)
# Requirement already satisfied: panel>=0.13.1 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from holoviews) (1.2.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from pandas>=0.20.0->holoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from pandas>=0.20.0->holoviews) (2022.1)
# Requirement already satisfied: typing-extensions in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from panel>=0.13.1->holoviews) (4.3.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from panel>=0.13.1->holoviews) (4.64.0)
# Requirement already satisfied: markdown in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from panel>=0.13.1->holoviews) (3.5.1)
# Requirement already satisfied: bokeh<3.3.0,>=3.1.1 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from panel>=0.13.1->holoviews) (3.1.1)
# Requirement already satisfied: mdit-py-plugins in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from panel>=0.13.1->holoviews) (0.4.0)
# Requirement already satisfied: linkify-it-py in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from panel>=0.13.1->holoviews) (2.0.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from panel>=0.13.1->holoviews) (2023.10.1)
# Requirement already satisfied: markdown-it-py in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from panel>=0.13.1->holoviews) (3.0.0)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from panel>=0.13.1->holoviews) (2.28.1)
# Requirement already satisfied: bleach in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from panel>=0.13.1->holoviews) (4.1.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from colorcet->holoviews) (0.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from packaging->holoviews) (3.0.9)
# Requirement already satisfied: contourpy>=1 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews) (1.0.5)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews) (6.0.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews) (9.2.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews) (3.0.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews) (6.1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.20.0->holoviews) (1.16.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from tqdm>=4.48.0->panel>=0.13.1->holoviews) (0.4.5)
# Requirement already satisfied: webencodings in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from bleach->panel>=0.13.1->holoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from linkify-it-py->panel>=0.13.1->holoviews) (1.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from markdown->panel>=0.13.1->holoviews) (7.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from markdown-it-py->panel>=0.13.1->holoviews) (0.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from requests->panel>=0.13.1->holoviews) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from requests->panel>=0.13.1->holoviews) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from requests->panel>=0.13.1->holoviews) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from requests->panel>=0.13.1->holoviews) (3.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from importlib-metadata>=4.4->markdown->panel>=0.13.1->holoviews) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\envs\ir_env\lib\site-packages (from Jinja2>=2.9->bokeh<3.3.0,>=3.1.1->panel>=0.13.1->holoviews) (2.1.1)

# %%
import pandas as pd
import holoviews as hv
from holoviews import opts, dim

hv.extension('matplotlib')
hv.output(fig='svg', size=500)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
import os
os.chdir('C:/Users/Lenovo/Skripsi/Chord Diagram')

port_df = pd.read_csv('KunjunganPort.csv')
two_port_df = port_df[~port_df['Port_Prev'].isnull()]
#two_port_df = pd.DataFrame()
two_port_df['port'] = two_port_df.apply(lambda x: f'{x["Port_Prev"]},{x["Port_Next"]}', axis=1)
port_connections = two_port_df['port'].value_counts().to_dict()
#port_connections = port_df['Count']
#two_port_df

# %%
connections = {}
for port_combo, value in port_connections.items():
    port_types = port_combo.split(',')
    for port_type in port_types:
        if port_type not in connections:
            connections[port_type] = {'targets': {x: value for x in port_types if x != port_type}}
        else:
            for target in port_types:
                if port_type == target:
                    continue
                if target in connections[port_type]['targets'].keys():
                    connections[port_type]['targets'][target] += value
                else:
                    connections[port_type]['targets'][target] = value

# %%
chords = pd.DataFrame(columns=['source', 'target', 'value'])
nodes_df = pd.DataFrame(columns=['name'])
for port_type, target_data in connections.items():

    # We want to insert into our nodes df and use that index as the numerical representation in the chords dataframe.
    if port_type not in nodes_df['name'].values:
        nodes_df = nodes_df.append(pd.Series([port_type], index=nodes_df.columns), ignore_index=True)
    type_id = int(nodes_df[nodes_df['name'] == port_type].index[0])


    for target, counts in target_data['targets'].items():
        if target not in nodes_df['name'].values:
            nodes_df = nodes_df.append(pd.Series([target], index=nodes_df.columns), ignore_index=True)
        target_id = int(nodes_df[nodes_df['name'] == target].index[0])

        # During our process in the last code block, we add each count twice:
        # Once for the source and once for the target. So, we want to make sure we add it only once.
        is_already_in = chords[(chords['source'] == target_id) & (chords['target'] == type_id)]
        if len(is_already_in) == 0:
            chords= chords.append(pd.Series([type_id, target_id, counts], index=chords.columns), ignore_index=True)

# Make sure our values are ints.
chords['value'] = chords['value'].astype('int')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_34476\1576350047.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nodes_df = nodes_df.append(pd.Series([port_type], index=nodes_df.columns), ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_34476\1576350047.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nodes_df = nodes_df.append(pd.Series([target], index=nodes_df.columns), ignore_index=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_34476\1576350047.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   chords= chords.append(pd.Series([type_id, target_id, counts], index=chords.columns), ignore_index=True)

# %%
nodes = hv.Dataset(nodes_df.reset_index(), 'index')
hv.Chord((chords, nodes)).opts(
    opts.Chord(cmap='Category20', edge_color=dim('source').astype(str), labels='name', node_color=dim('index').astype(str)))
# Out:
# :Chord   [source,target]   (value)
