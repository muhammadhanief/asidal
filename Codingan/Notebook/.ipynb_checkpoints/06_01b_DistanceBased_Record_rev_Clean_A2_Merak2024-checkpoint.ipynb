# %% [markdown]
# # Initialialize

# %%
from sedona.register import SedonaRegistrator
SedonaRegistrator.registerAll(spark)
# Out:
# True

# %%
import subprocess
import sys

# %%
GITLAB_USER = "read aistt"
GITLAB_TOKEN = "J1KkstArfyXB6dZvFchN"
git_package = f"git+https://(GITLAB_USER):(GITLAB_TOKEN)@code.officialstatistics.org/trade-task-team-phase-1/ais.git"
std_out = subprocess.run([sys.executable, "-m", "pip", "install", git_package], capture_output=True, text=True) .stdout
print(std_out)
# Out:
# Collecting git+https://%28GITLAB_USER%29:****@code.officialstatistics.org/trade-task-team-phase-1/ais.git
#   Cloning https://%28GITLAB_USER%29:****@code.officialstatistics.org/trade-task-team-phase-1/ais.git to /tmp/pip-req-build-h36f6fvc

# %%
GITLAB_USER = 'ml_group_read_only'
GITLAB_TOKEN = 'eac7ZwiseRdeLwmBsrsm'

# Main: for using from current issued version
git_package = f"git+https://{GITLAB_USER}:{GITLAB_TOKEN}@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git"

std_out = subprocess.run([sys.executable, "-m", "pip", "install",git_package], capture_output=True, text=True).stdout
print(std_out)
# Out:
# Collecting git+https://ml_group_read_only:****@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git
#   Cloning https://ml_group_read_only:****@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git to /tmp/pip-req-build-dd3afxsp
#   Resolved https://ml_group_read_only:****@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git to commit 89f1aab64fee28c2f86e86d6fa7b55118882b1e8
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: unece-ais
#   Building wheel for unece-ais (setup.py): started
#   Building wheel for unece-ais (setup.py): finished with status 'done'
#   Created wheel for unece-ais: filename=unece_ais-0.0.4-py3-none-any.whl size=12493 sha256=c28acf46a093f0e4eaab22474fd32c41a2fd4bffdba5725dcfb2f4124a35fd6e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m5cuzzxx/wheels/61/b5/f9/bcf024b104169c32950c03a4605d2d07ea9da07cae7bed5e3e
# Successfully built unece-ais
# Installing collected packages: unece-ais
# Successfully installed unece-ais-0.0.4

# %%
from pyspark.sql import functions as F
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, date_format, count, countDistinct, when, expr, unix_timestamp
from pyspark.sql.functions import year, month, dayofmonth, hour, minute, second
from pyspark.sql.functions import monotonically_increasing_id, lead, lag, abs, row_number
from pyspark.sql.functions import concat_ws, split, lit, min, max
from pyspark.sql.types import IntegerType, StringType, StructType
from pyspark.sql.window import Window

from shapely.geometry import Point, Polygon, mapping
from IPython.display import HTML
from ais import functions as af
# from unece_ais import unece_ais as un
from multiprocessing import Pool

# %%
import h3.api.numpy_int as h3int
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns
import pandas as pd
import numpy as np
import calendar
import base64
import folium
import tqdm
import h3
# Out:
# generated new fontManager

# %%
pd.set_option('display.max_columns', None) #Show all columns in pandas df
pd.set_option('display.max_rows', 100) #Show 100 rows in pandas df
pd.options.display.float_format = '{:.10f}'.format #Show float with 10 decimal points in pandas df

from IPython.core.interactiveshell import InteractiveShell #allow multiple outputs in one jupyter cell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Path
base_path = "s3a://ungp-ais-data-historical-backup/user_temp/"
path_unique = base_path + "222011349/"

# %% [markdown]
# # Data

# %% [markdown]
# ## Masuk-Keluar Indonesia

# %%
# Read Data
result_out_in = spark.read.parquet(path_unique + "data-ais-masuk-keluar-merak-2024-rev.parquet", header=True)

# %% [markdown]
# ### Keluar Pelabuhan

# %%
result_out_port = result_out_in.filter(
    (
        (col("position") == "in port") & 
        (col("keluar_pelabuhan") == "keluar")
    ) |
    (
        (col("position") == "out port") & 
        (col("keluar_pelabuhan") == "keluar")
    
    )
)

# %%
result_out_port.count()
# Out:
# 18688

# %% [markdown]
# # Waktu di Port Indonesia

# %%
# Membuat window specification
window_spec = Window.partitionBy("mmsi").orderBy("dt_pos_utc")

# Menambahkan kolom selisih waktu
result_diff = result_out_in.withColumn(
    "time",
    unix_timestamp(F.lead("dt_pos_utc").over(window_spec)) - unix_timestamp("dt_pos_utc")
)

# %% [markdown]
# ## Hitung

# %%
# Mendapatkan baris-baris dengan urutan waktu
window_spec = Window.partitionBy("mmsi").orderBy("dt_pos_utc", "Port")

# Tambahkan kolom next_position
result_diff = result_diff.withColumn("next_position", F.lead("position", 1).over(window_spec))

# %%
# Definisikan window specification
window_spec = Window.partitionBy("mmsi").orderBy("dt_pos_utc", "Port")

# Tentukan apakah Port sama dengan baris sebelumnya
result_diff = result_diff.withColumn(
    "same_port_as_previous",
    F.when(
        F.lag("Port").over(window_spec) == F.col("Port"), 
        True
    ).otherwise(False)
)

# %%
# Kolom Port sama dengan baris sebelumnya untuk baris setelahnya
result_diff = result_diff.withColumn("same_port_next", F.lead("same_port_as_previous").over(window_spec))

# %%
# Tambahkan kolom next_position
result_diff = result_diff.withColumn("next_keluar", F.lead("keluar_pelabuhan", 1).over(window_spec))

# %%
# Hitung Durasi

# Definisikan window specification
window_spec = Window.partitionBy("mmsi").orderBy("dt_pos_utc", "Port")

# Menambah kolom baru dengan nilai diff_time dari baris saat ini ditambah diff_time dari baris sebelumnya
result_diff = result_diff.withColumn(
    "diff_time",
    result_diff["time"] + lead("time", 1).over(window_spec)
)

# Menentukan kondisi untuk menambahkan nilai diff_time dari baris sebelumnya
condition = (col("position") == "in port") & (col("next_position") == "in port") & (col("masuk_pelabuhan") == "masuk") & (col("same_port_next") == True) & (col("next_keluar") == "keluar")

# Mengatur nilai baru untuk baris yang memenuhi kondisi
result_diff = result_diff.withColumn("diff_time", when(condition, result_diff["diff_time"]).otherwise("-"))

# %%
# Daftar kolom yang ingin dijatuhkan
kolom_drop = ["next_position", "same_port_as_previous", "same_port_next", "next_keluar"]

# Menjatuhkan kolom yang tidak diperlukan dari DataFrame
result_diff = result_diff.drop(*kolom_drop)

# %%
# Filter in port
result_diff = result_diff.filter(col("position") == "in port")

# %%
# Filter diff_time
result_diff = result_diff.filter(col("diff_time") != "-")

# %% [markdown]
# ## Konversi

# %%
# Konversi durasi ke jam
result_diff = result_diff.withColumn(
    "diff_time_hours",
    col("diff_time") / 3600
)
result_diff = result_diff.withColumn(
    "diff_time_minutes",
    col("diff_time") / 60
)

# %%
# Skema kosong untuk DataFrame
schema = StructType([])

# Membuat DataFrame kosong
time_in_port = spark.createDataFrame([], schema)

time_in_port = result_diff.select("mmsi", "Port", "fc_vessel", "vessel_type", "ns_vessel", "diff_time", "diff_time_minutes", "diff_time_hours")

# %% [markdown]
# ## Download csv

# %%
def create_download_link(df, title, filename):
    csv = df.to_csv(index = False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload, title=title, filename=filename)
    return HTML(html)

# %%
# DataFrame Spark
# rekaman_per_bulan = spark.createDataFrame(rekaman_per_bulan)

# Export ke Pandas DataFrame
time_in_port = time_in_port.toPandas()

# Download Data
create_download_link(time_in_port, title="time_in_port", filename="time_in_port.csv")
# Out:
# <a download="time_in_port.csv" href="data:text/csv;base64,..." target="_blank">time_in_port</a>

# %% [markdown]
# ## Visualisasi

# %%
# Mengambil kolom diff_time_hours dari DataFrame time_in_port
diff_time_hours = time_in_port.select("Port", "vessel_type", "diff_time_hours").toPandas()

# %%
# Membuat box plot
sns.boxplot(y=diff_time_hours["diff_time_hours"])
plt.title("Box Plot Durasi di Pelabuhan")
plt.ylabel("Durasi (jam)")
plt.xlabel("Durasi di Pelabuhan")
plt.show()
# Out:
# <Axes: ylabel='diff_time_hours'>
# Text(0.5, 1.0, 'Box Plot Durasi di Pelabuhan')
# Text(0, 0.5, 'Durasi (jam)')
# Text(0.5, 0, 'Durasi di Pelabuhan')

# %%
# Mengambil kolom diff_time_hours dari DataFrame time_in_port
diff_time_minutes = time_in_port.select("Port", "vessel_type", "diff_time_minutes").toPandas()

# %%
# Membuat box plot
sns.boxplot(y=diff_time_minutes["diff_time_minutes"])
plt.title("Box Plot Durasi di Pelabuhan")
plt.ylabel("Durasi (menit)")
plt.xlabel("Durasi di Pelabuhan")
plt.show()
# Out:
# <Axes: ylabel='diff_time_minutes'>
# Text(0.5, 1.0, 'Box Plot Durasi di Pelabuhan')
# Text(0, 0.5, 'Durasi (menit)')
# Text(0.5, 0, 'Durasi di Pelabuhan')

# %% [markdown]
# ## Outlier

# %%
outlier_data = time_in_port.filter(col("diff_time_hours") > 6)

# %%
outlier_data.count()
# Out:
# 241

# %%
outlier_data = outlier_data.orderBy(col("diff_time_hours").desc())

# %%
outlier_data.show(outlier_data.count(), truncate = False)
# Out:
# +---------+--------------+---------+-----------+----------------------+---------+------------------+------------------+
# |mmsi     |Port          |fc_vessel|vessel_type|ns_vessel             |diff_time|diff_time_minutes |diff_time_hours   |
# +---------+--------------+---------+-----------+----------------------+---------+------------------+------------------+
# |563165800|Tanjung Sekong|Singapore|Passenger  |Under Way Using Engine|2577945  |42965.75          |716.0958333333333 |
# |525200335|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |1093884  |18231.4           |303.8566666666667 |
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |740809   |12346.816666666668|205.78027777777777|
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|725381   |12089.683333333332|201.4947222222222 |
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|676984   |11283.066666666668|188.0511111111111 |
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|549950   |9165.833333333334 |152.76388888888889|
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |538379   |8972.983333333334 |149.54972222222221|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|528919   |8815.316666666668 |146.92194444444445|
# |525100805|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|497931   |8298.85           |138.31416666666667|
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|472378   |7872.966666666666 |131.2161111111111 |
# |525200335|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |442003   |7366.716666666666 |122.7786111111111 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|426805   |7113.416666666667 |118.55694444444444|
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|415322   |6922.033333333334 |115.36722222222222|
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |377689   |6294.816666666667 |104.91361111111111|
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|357223   |5953.716666666666 |99.2286111111111  |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|333144   |5552.4            |92.54             |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|332090   |5534.833333333333 |92.24722222222222 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|323752   |5395.866666666667 |89.93111111111111 |
# |525200126|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|317877   |5297.95           |88.29916666666666 |
# |525005177|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|300178   |5002.966666666666 |83.38277777777778 |
# |525005232|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |297673   |4961.216666666666 |82.68694444444445 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|296361   |4939.35           |82.3225           |
# |525002086|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |282463   |4707.716666666666 |78.46194444444444 |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|273584   |4559.733333333334 |75.99555555555555 |
# |525015491|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|272571   |4542.85           |75.71416666666667 |
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|266081   |4434.683333333333 |73.9113888888889  |
# |525100493|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|265130   |4418.833333333333 |73.64722222222223 |
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|263979   |4399.65           |73.3275           |
# |525100600|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|252081   |4201.35           |70.0225           |
# |525004089|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|248503   |4141.716666666666 |69.0286111111111  |
# |525015375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|237223   |3953.7166666666667|65.89527777777778 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|234818   |3913.633333333333 |65.22722222222222 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|230777   |3846.2833333333333|64.10472222222222 |
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|223177   |3719.616666666667 |61.993611111111115|
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|201223   |3353.7166666666667|55.89527777777778 |
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|197465   |3291.0833333333335|54.85138888888889 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|195046   |3250.766666666667 |54.17944444444444 |
# |525001136|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|187302   |3121.7            |52.028333333333336|
# |525100777|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|186242   |3104.0333333333333|51.73388888888889 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|185776   |3096.266666666667 |51.60444444444445 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|177925   |2965.4166666666665|49.423611111111114|
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|172390   |2873.1666666666665|47.88611111111111 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |172121   |2868.6833333333334|47.81138888888889 |
# |525015491|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|170449   |2840.8166666666666|47.346944444444446|
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|163572   |2726.2            |45.43666666666667 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |162385   |2706.4166666666665|45.106944444444444|
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |159442   |2657.366666666667 |44.28944444444444 |
# |525015491|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|153921   |2565.35           |42.755833333333335|
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|153421   |2557.016666666667 |42.61694444444444 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|151184   |2519.733333333333 |41.995555555555555|
# |525004089|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|139641   |2327.35           |38.78916666666667 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|136709   |2278.483333333333 |37.97472222222222 |
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|134983   |2249.7166666666667|37.49527777777778 |
# |525100600|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|131988   |2199.8            |36.663333333333334|
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|126969   |2116.15           |35.26916666666666 |
# |525005232|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |116308   |1938.4666666666667|32.30777777777778 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|114539   |1908.9833333333333|31.816388888888888|
# |525019408|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |107083   |1784.7166666666667|29.745277777777776|
# |525100375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|105884   |1764.7333333333333|29.412222222222223|
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |102540   |1709.0            |28.483333333333334|
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|99819    |1663.65           |27.7275           |
# |525200924|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |97768    |1629.4666666666667|27.157777777777778|
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|94122    |1568.7            |26.145            |
# |525002086|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |92881    |1548.0166666666667|25.80027777777778 |
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |91315    |1521.9166666666667|25.365277777777777|
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|90945    |1515.75           |25.2625           |
# |525015375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|90277    |1504.6166666666666|25.076944444444443|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|86621    |1443.6833333333334|24.06138888888889 |
# |525015375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|85537    |1425.6166666666666|23.760277777777777|
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |82936    |1382.2666666666667|23.037777777777777|
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|78545    |1309.0833333333333|21.818055555555556|
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|78057    |1300.95           |21.6825           |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|77494    |1291.5666666666666|21.52611111111111 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|75960    |1266.0            |21.1              |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|72972    |1216.2            |20.27             |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|72888    |1214.8            |20.246666666666666|
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |67994    |1133.2333333333333|18.88722222222222 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |64561    |1076.0166666666667|17.933611111111112|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |63744    |1062.4            |17.706666666666667|
# |525019468|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|63700    |1061.6666666666667|17.694444444444443|
# |525006222|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |63253    |1054.2166666666667|17.57027777777778 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|62754    |1045.9            |17.43166666666667 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|61922    |1032.0333333333333|17.200555555555557|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|61113    |1018.55           |16.975833333333334|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|59576    |992.9333333333333 |16.54888888888889 |
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|58058    |967.6333333333333 |16.127222222222223|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|57176    |952.9333333333333 |15.882222222222222|
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |56598    |943.3             |15.721666666666666|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|55772    |929.5333333333333 |15.492222222222223|
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |54254    |904.2333333333333 |15.070555555555556|
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|54085    |901.4166666666666 |15.02361111111111 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|53706    |895.1             |14.918333333333333|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |52701    |878.35            |14.639166666666666|
# |525001121|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |51892    |864.8666666666667 |14.414444444444445|
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|51703    |861.7166666666667 |14.361944444444445|
# |525100493|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|50571    |842.85            |14.0475           |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |49172    |819.5333333333333 |13.658888888888889|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|48890    |814.8333333333334 |13.580555555555556|
# |525022100|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|47659    |794.3166666666667 |13.238611111111112|
# |525002086|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |47022    |783.7             |13.061666666666667|
# |525100375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|46415    |773.5833333333334 |12.893055555555556|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|46058    |767.6333333333333 |12.793888888888889|
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |45148    |752.4666666666667 |12.54111111111111 |
# |525015932|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |43962    |732.7             |12.211666666666666|
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|42923    |715.3833333333333 |11.923055555555555|
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|42197    |703.2833333333333 |11.721388888888889|
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |42102    |701.7             |11.695            |
# |525002087|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|42098    |701.6333333333333 |11.693888888888889|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|41433    |690.55            |11.509166666666667|
# |525006222|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |41230    |687.1666666666666 |11.452777777777778|
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |41193    |686.55            |11.4425           |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|40971    |682.85            |11.380833333333333|
# |525015932|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |40927    |682.1166666666667 |11.368611111111111|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|40912    |681.8666666666667 |11.364444444444445|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|40908    |681.8             |11.363333333333333|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|40108    |668.4666666666667 |11.141111111111112|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |39857    |664.2833333333333 |11.071388888888889|
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|39607    |660.1166666666667 |11.001944444444444|
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|39578    |659.6333333333333 |10.99388888888889 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|38869    |647.8166666666667 |10.796944444444444|
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|38753    |645.8833333333333 |10.764722222222222|
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|38231    |637.1833333333333 |10.619722222222222|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|38229    |637.15            |10.619166666666667|
# |525005232|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |38221    |637.0166666666667 |10.616944444444444|
# |525100777|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|38145    |635.75            |10.595833333333333|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |38015    |633.5833333333334 |10.559722222222222|
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |37023    |617.05            |10.284166666666666|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|36894    |614.9             |10.248333333333333|
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|36642    |610.7             |10.178333333333333|
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |36503    |608.3833333333333 |10.139722222222222|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |36110    |601.8333333333334 |10.030555555555555|
# |525019468|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|36055    |600.9166666666666 |10.015277777777778|
# |525100375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|35959    |599.3166666666667 |9.988611111111112 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|35930    |598.8333333333334 |9.980555555555556 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|35922    |598.7             |9.978333333333333 |
# |525001121|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |35714    |595.2333333333333 |9.920555555555556 |
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |34980    |583.0             |9.716666666666667 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|34902    |581.7             |9.695             |
# |525004089|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|34724    |578.7333333333333 |9.645555555555555 |
# |525019408|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|34601    |576.6833333333333 |9.61138888888889  |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|34255    |570.9166666666666 |9.515277777777778 |
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|33524    |558.7333333333333 |9.312222222222223 |
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |33332    |555.5333333333333 |9.258888888888889 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |32497    |541.6166666666667 |9.026944444444444 |
# |525022300|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|32483    |541.3833333333333 |9.023055555555555 |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|32466    |541.1             |9.018333333333333 |
# |525015868|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|32327    |538.7833333333333 |8.979722222222222 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |32209    |536.8166666666667 |8.946944444444444 |
# |525022300|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|32114    |535.2333333333333 |8.920555555555556 |
# |525005232|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |32105    |535.0833333333334 |8.918055555555556 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|32047    |534.1166666666667 |8.901944444444444 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |31915    |531.9166666666666 |8.865277777777777 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|31866    |531.1             |8.851666666666667 |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|31860    |531.0             |8.85              |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|31682    |528.0333333333333 |8.800555555555556 |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|31269    |521.15            |8.685833333333333 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|31001    |516.6833333333333 |8.61138888888889  |
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |30882    |514.7             |8.578333333333333 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|30821    |513.6833333333333 |8.561388888888889 |
# |525001068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|30747    |512.45            |8.540833333333333 |
# |525002086|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |30714    |511.9             |8.531666666666666 |
# |525019468|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|30691    |511.51666666666665|8.525277777777777 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |29989    |499.81666666666666|8.330277777777777 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |29737    |495.6166666666667 |8.260277777777778 |
# |525004089|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|29677    |494.6166666666667 |8.243611111111111 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|29658    |494.3             |8.238333333333333 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |29635    |493.9166666666667 |8.231944444444444 |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|29568    |492.8             |8.213333333333333 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |29408    |490.1333333333333 |8.168888888888889 |
# |525019467|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|29127    |485.45            |8.090833333333334 |
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|28972    |482.8666666666667 |8.047777777777778 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |28659    |477.65            |7.960833333333333 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|28590    |476.5             |7.941666666666666 |
# |525015932|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |28577    |476.28333333333336|7.938055555555556 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|28023    |467.05            |7.784166666666667 |
# |525100375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|28021    |467.01666666666665|7.783611111111111 |
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27796    |463.26666666666665|7.721111111111111 |
# |525002088|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27649    |460.81666666666666|7.6802777777777775|
# |525019468|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27580    |459.6666666666667 |7.661111111111111 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27548    |459.1333333333333 |7.652222222222222 |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27247    |454.1166666666667 |7.568611111111111 |
# |525300391|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27182    |453.03333333333336|7.5505555555555555|
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|26928    |448.8             |7.48              |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|26923    |448.71666666666664|7.478611111111111 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |26849    |447.48333333333335|7.458055555555555 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |26776    |446.26666666666665|7.437777777777778 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|26421    |440.35            |7.339166666666666 |
# |525006222|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |26354    |439.23333333333335|7.320555555555556 |
# |525019468|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|26351    |439.18333333333334|7.3197222222222225|
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|26196    |436.6             |7.276666666666666 |
# |525022300|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|25955    |432.5833333333333 |7.209722222222222 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |25579    |426.31666666666666|7.105277777777777 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |25572    |426.2             |7.1033333333333335|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|25558    |425.96666666666664|7.099444444444444 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|25180    |419.6666666666667 |6.9944444444444445|
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24962    |416.03333333333336|6.933888888888889 |
# |525005232|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |24836    |413.93333333333334|6.898888888888889 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24678    |411.3             |6.855             |
# |525015932|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |24666    |411.1             |6.851666666666667 |
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |24620    |410.3333333333333 |6.838888888888889 |
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24564    |409.4             |6.823333333333333 |
# |525022300|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24487    |408.1166666666667 |6.801944444444445 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24472    |407.8666666666667 |6.797777777777778 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24369    |406.15            |6.769166666666667 |
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24029    |400.48333333333335|6.674722222222222 |
# |525015491|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24013    |400.21666666666664|6.670277777777778 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23992    |399.8666666666667 |6.664444444444444 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |23986    |399.76666666666665|6.6627777777777775|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23980    |399.6666666666667 |6.661111111111111 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23955    |399.25            |6.654166666666667 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23609    |393.48333333333335|6.558055555555556 |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23530    |392.1666666666667 |6.536111111111111 |
# |525001068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23513    |391.8833333333333 |6.5313888888888885|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23395    |389.9166666666667 |6.498611111111111 |
# |525019467|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23369    |389.48333333333335|6.491388888888889 |
# |525012279|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23347    |389.1166666666667 |6.485277777777778 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |23317    |388.6166666666667 |6.476944444444444 |
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23317    |388.6166666666667 |6.476944444444444 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23305    |388.4166666666667 |6.473611111111111 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23065    |384.4166666666667 |6.406944444444444 |
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22907    |381.78333333333336|6.3630555555555555|
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22899    |381.65            |6.360833333333333 |
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22880    |381.3333333333333 |6.355555555555555 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22878    |381.3             |6.355             |
# |525019408|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22809    |380.15            |6.335833333333333 |
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22778    |379.6333333333333 |6.327222222222222 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22702    |378.3666666666667 |6.306111111111111 |
# |525100493|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22698    |378.3             |6.305             |
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22689    |378.15            |6.3025            |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22645    |377.4166666666667 |6.290277777777778 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22606    |376.76666666666665|6.279444444444445 |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22281    |371.35            |6.189166666666667 |
# |525019408|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22276    |371.26666666666665|6.187777777777778 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22261    |371.01666666666665|6.183611111111111 |
# |525022300|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22260    |371.0             |6.183333333333334 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22251    |370.85            |6.180833333333333 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |21898    |364.96666666666664|6.082777777777777 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|21784    |363.06666666666666|6.051111111111111 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|21702    |361.7             |6.028333333333333 |
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|21649    |360.81666666666666|6.0136111111111115|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|21624    |360.4             |6.006666666666667 |
# +---------+--------------+---------+-----------+----------------------+---------+------------------+------------------+

# %%
outlier_data = outlier_data.orderBy("mmsi", "Port")

# %%
outlier_data.show(outlier_data.count(), truncate = False)
# Out:
# +---------+--------------+---------+-----------+----------------------+---------+------------------+------------------+
# |mmsi     |Port          |fc_vessel|vessel_type|ns_vessel             |diff_time|diff_time_minutes |diff_time_hours   |
# +---------+--------------+---------+-----------+----------------------+---------+------------------+------------------+
# |525001068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|30747    |512.45            |8.540833333333333 |
# |525001068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23513    |391.8833333333333 |6.5313888888888885|
# |525001121|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |51892    |864.8666666666667 |14.414444444444445|
# |525001121|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |35714    |595.2333333333333 |9.920555555555556 |
# |525001136|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|187302   |3121.7            |52.028333333333336|
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|223177   |3719.616666666667 |61.993611111111115|
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|676984   |11283.066666666668|188.0511111111111 |
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22907    |381.78333333333336|6.3630555555555555|
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|415322   |6922.033333333334 |115.36722222222222|
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|549950   |9165.833333333334 |152.76388888888889|
# |525002068|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|21649    |360.81666666666666|6.0136111111111115|
# |525002086|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |92881    |1548.0166666666667|25.80027777777778 |
# |525002086|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |47022    |783.7             |13.061666666666667|
# |525002086|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |30714    |511.9             |8.531666666666666 |
# |525002086|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |282463   |4707.716666666666 |78.46194444444444 |
# |525002087|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|42098    |701.6333333333333 |11.693888888888889|
# |525002088|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27649    |460.81666666666666|7.6802777777777775|
# |525004089|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|139641   |2327.35           |38.78916666666667 |
# |525004089|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|248503   |4141.716666666666 |69.0286111111111  |
# |525004089|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|29677    |494.6166666666667 |8.243611111111111 |
# |525004089|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|34724    |578.7333333333333 |9.645555555555555 |
# |525005177|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|300178   |5002.966666666666 |83.38277777777778 |
# |525005232|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |297673   |4961.216666666666 |82.68694444444445 |
# |525005232|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |116308   |1938.4666666666667|32.30777777777778 |
# |525005232|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |38221    |637.0166666666667 |10.616944444444444|
# |525005232|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |24836    |413.93333333333334|6.898888888888889 |
# |525005232|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |32105    |535.0833333333334 |8.918055555555556 |
# |525006222|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |41230    |687.1666666666666 |11.452777777777778|
# |525006222|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |26354    |439.23333333333335|7.320555555555556 |
# |525006222|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |63253    |1054.2166666666667|17.57027777777778 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|75960    |1266.0            |21.1              |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|40108    |668.4666666666667 |11.141111111111112|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|25558    |425.96666666666664|7.099444444444444 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|35922    |598.7             |9.978333333333333 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|332090   |5534.833333333333 |92.24722222222222 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|30821    |513.6833333333333 |8.561388888888889 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|86621    |1443.6833333333334|24.06138888888889 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|53706    |895.1             |14.918333333333333|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|151184   |2519.733333333333 |41.995555555555555|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|426805   |7113.416666666667 |118.55694444444444|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|34255    |570.9166666666666 |9.515277777777778 |
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|48890    |814.8333333333334 |13.580555555555556|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|61113    |1018.55           |16.975833333333334|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|46058    |767.6333333333333 |12.793888888888889|
# |525006235|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|234818   |3913.633333333333 |65.22722222222222 |
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |41193    |686.55            |11.4425           |
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |24620    |410.3333333333333 |6.838888888888889 |
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |36503    |608.3833333333333 |10.139722222222222|
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |33332    |555.5333333333333 |9.258888888888889 |
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |102540   |1709.0            |28.483333333333334|
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |91315    |1521.9166666666667|25.365277777777777|
# |525007397|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |82936    |1382.2666666666667|23.037777777777777|
# |525012279|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23347    |389.1166666666667 |6.485277777777778 |
# |525015375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|85537    |1425.6166666666666|23.760277777777777|
# |525015375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|237223   |3953.7166666666667|65.89527777777778 |
# |525015375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|90277    |1504.6166666666666|25.076944444444443|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|36894    |614.9             |10.248333333333333|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|61922    |1032.0333333333333|17.200555555555557|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|21624    |360.4             |6.006666666666667 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|40908    |681.8             |11.363333333333333|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|31866    |531.1             |8.851666666666667 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |25572    |426.2             |7.1033333333333335|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|55772    |929.5333333333333 |15.492222222222223|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |49172    |819.5333333333333 |13.658888888888889|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|59576    |992.9333333333333 |16.54888888888889 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27548    |459.1333333333333 |7.652222222222222 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|41433    |690.55            |11.509166666666667|
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|28590    |476.5             |7.941666666666666 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|185776   |3096.266666666667 |51.60444444444445 |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24678    |411.3             |6.855             |
# |525015377|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|57176    |952.9333333333333 |15.882222222222222|
# |525015491|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|153921   |2565.35           |42.755833333333335|
# |525015491|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|170449   |2840.8166666666666|47.346944444444446|
# |525015491|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|272571   |4542.85           |75.71416666666667 |
# |525015491|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24013    |400.21666666666664|6.670277777777778 |
# |525015868|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|32327    |538.7833333333333 |8.979722222222222 |
# |525015932|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |28577    |476.28333333333336|7.938055555555556 |
# |525015932|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |43962    |732.7             |12.211666666666666|
# |525015932|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |40927    |682.1166666666667 |11.368611111111111|
# |525015932|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |24666    |411.1             |6.851666666666667 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|21702    |361.7             |6.028333333333333 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24472    |407.8666666666667 |6.797777777777778 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22645    |377.4166666666667 |6.290277777777778 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|29658    |494.3             |8.238333333333333 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|136709   |2278.483333333333 |37.97472222222222 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|34902    |581.7             |9.695             |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|72888    |1214.8            |20.246666666666666|
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|35930    |598.8333333333334 |9.980555555555556 |
# |525016714|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|177925   |2965.4166666666665|49.423611111111114|
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|333144   |5552.4            |92.54             |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|357223   |5953.716666666666 |99.2286111111111  |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|273584   |4559.733333333334 |75.99555555555555 |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|39578    |659.6333333333333 |10.99388888888889 |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|153421   |2557.016666666667 |42.61694444444444 |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|54085    |901.4166666666666 |15.02361111111111 |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|31860    |531.0             |8.85              |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|31682    |528.0333333333333 |8.800555555555556 |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|31269    |521.15            |8.685833333333333 |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|163572   |2726.2            |45.43666666666667 |
# |525019293|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|26928    |448.8             |7.48              |
# |525019408|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22809    |380.15            |6.335833333333333 |
# |525019408|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22276    |371.26666666666665|6.187777777777778 |
# |525019408|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |107083   |1784.7166666666667|29.745277777777776|
# |525019408|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|34601    |576.6833333333333 |9.61138888888889  |
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24029    |400.48333333333335|6.674722222222222 |
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27796    |463.26666666666665|7.721111111111111 |
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|78057    |1300.95           |21.6825           |
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22689    |378.15            |6.3025            |
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|472378   |7872.966666666666 |131.2161111111111 |
# |525019409|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22778    |379.6333333333333 |6.327222222222222 |
# |525019467|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|29127    |485.45            |8.090833333333334 |
# |525019467|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23369    |389.48333333333335|6.491388888888889 |
# |525019468|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|26351    |439.18333333333334|7.3197222222222225|
# |525019468|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27580    |459.6666666666667 |7.661111111111111 |
# |525019468|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|36055    |600.9166666666666 |10.015277777777778|
# |525019468|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|63700    |1061.6666666666667|17.694444444444443|
# |525019468|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|30691    |511.51666666666665|8.525277777777777 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|26421    |440.35            |7.339166666666666 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22899    |381.65            |6.360833333333333 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22606    |376.76666666666665|6.279444444444445 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|21784    |363.06666666666666|6.051111111111111 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|25180    |419.6666666666667 |6.9944444444444445|
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22251    |370.85            |6.180833333333333 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|230777   |3846.2833333333333|64.10472222222222 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22261    |371.01666666666665|6.183611111111111 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|195046   |3250.766666666667 |54.17944444444444 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23065    |384.4166666666667 |6.406944444444444 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|26923    |448.71666666666664|7.478611111111111 |
# |525021421|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24962    |416.03333333333336|6.933888888888889 |
# |525022100|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|47659    |794.3166666666667 |13.238611111111112|
# |525022300|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24487    |408.1166666666667 |6.801944444444445 |
# |525022300|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|32114    |535.2333333333333 |8.920555555555556 |
# |525022300|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|32483    |541.3833333333333 |9.023055555555555 |
# |525022300|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|25955    |432.5833333333333 |7.209722222222222 |
# |525022300|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22260    |371.0             |6.183333333333334 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22878    |381.3             |6.355             |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|31001    |516.6833333333333 |8.61138888888889  |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|32047    |534.1166666666667 |8.901944444444444 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|39607    |660.1166666666667 |11.001944444444444|
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|725381   |12089.683333333332|201.4947222222222 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|296361   |4939.35           |82.3225           |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|94122    |1568.7            |26.145            |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23609    |393.48333333333335|6.558055555555556 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|51703    |861.7166666666667 |14.361944444444445|
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|126969   |2116.15           |35.26916666666666 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|62754    |1045.9            |17.43166666666667 |
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|42923    |715.3833333333333 |11.923055555555555|
# |525023144|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22702    |378.3666666666667 |6.306111111111111 |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|99819    |1663.65           |27.7275           |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27247    |454.1166666666667 |7.568611111111111 |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23530    |392.1666666666667 |6.536111111111111 |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|72972    |1216.2            |20.27             |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|29568    |492.8             |8.213333333333333 |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22281    |371.35            |6.189166666666667 |
# |525024295|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|32466    |541.1             |9.018333333333333 |
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |377689   |6294.816666666667 |104.91361111111111|
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |740809   |12346.816666666668|205.78027777777777|
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |37023    |617.05            |10.284166666666666|
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |538379   |8972.983333333334 |149.54972222222221|
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |34980    |583.0             |9.716666666666667 |
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |56598    |943.3             |15.721666666666666|
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |45148    |752.4666666666667 |12.54111111111111 |
# |525100336|Tanjung Sekong|Indonesia|Passenger  |At Anchor             |30882    |514.7             |8.578333333333333 |
# |525100375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|35959    |599.3166666666667 |9.988611111111112 |
# |525100375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|28021    |467.01666666666665|7.783611111111111 |
# |525100375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|46415    |773.5833333333334 |12.893055555555556|
# |525100375|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|105884   |1764.7333333333333|29.412222222222223|
# |525100493|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|50571    |842.85            |14.0475           |
# |525100493|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22698    |378.3             |6.305             |
# |525100493|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|265130   |4418.833333333333 |73.64722222222223 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |32497    |541.6166666666667 |9.026944444444444 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |29635    |493.9166666666667 |8.231944444444444 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |42102    |701.7             |11.695            |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |67994    |1133.2333333333333|18.88722222222222 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |64561    |1076.0166666666667|17.933611111111112|
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |159442   |2657.366666666667 |44.28944444444444 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |21898    |364.96666666666664|6.082777777777777 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |23317    |388.6166666666667 |6.476944444444444 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |54254    |904.2333333333333 |15.070555555555556|
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |26849    |447.48333333333335|7.458055555555555 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |32209    |536.8166666666667 |8.946944444444444 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |26776    |446.26666666666665|7.437777777777778 |
# |525100582|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |29408    |490.1333333333333 |8.168888888888889 |
# |525100600|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|252081   |4201.35           |70.0225           |
# |525100600|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|131988   |2199.8            |36.663333333333334|
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|201223   |3353.7166666666667|55.89527777777778 |
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|26196    |436.6             |7.276666666666666 |
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23317    |388.6166666666667 |6.476944444444444 |
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|197465   |3291.0833333333335|54.85138888888889 |
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|90945    |1515.75           |25.2625           |
# |525100633|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|263979   |4399.65           |73.3275           |
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|36642    |610.7             |10.178333333333333|
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|22880    |381.3333333333333 |6.355555555555555 |
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|134983   |2249.7166666666667|37.49527777777778 |
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|28972    |482.8666666666667 |8.047777777777778 |
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|33524    |558.7333333333333 |9.312222222222223 |
# |525100688|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|42197    |703.2833333333333 |11.721388888888889|
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|172390   |2873.1666666666665|47.88611111111111 |
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|78545    |1309.0833333333333|21.818055555555556|
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|38231    |637.1833333333333 |10.619722222222222|
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|38753    |645.8833333333333 |10.764722222222222|
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|266081   |4434.683333333333 |73.9113888888889  |
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|58058    |967.6333333333333 |16.127222222222223|
# |525100695|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24564    |409.4             |6.823333333333333 |
# |525100777|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|186242   |3104.0333333333333|51.73388888888889 |
# |525100777|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|38145    |635.75            |10.595833333333333|
# |525100805|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|497931   |8298.85           |138.31416666666667|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |28659    |477.65            |7.960833333333333 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |38015    |633.5833333333334 |10.559722222222222|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |39857    |664.2833333333333 |11.071388888888889|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |29989    |499.81666666666666|8.330277777777777 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |52701    |878.35            |14.639166666666666|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |31915    |531.9166666666666 |8.865277777777777 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |36110    |601.8333333333334 |10.030555555555555|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |25579    |426.31666666666666|7.105277777777777 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |63744    |1062.4            |17.706666666666667|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |172121   |2868.6833333333334|47.81138888888889 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |29737    |495.6166666666667 |8.260277777777778 |
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |162385   |2706.4166666666665|45.106944444444444|
# |525119018|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |23986    |399.76666666666665|6.6627777777777775|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23955    |399.25            |6.654166666666667 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|40912    |681.8666666666667 |11.364444444444445|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|528919   |8815.316666666668 |146.92194444444445|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|323752   |5395.866666666667 |89.93111111111111 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23980    |399.6666666666667 |6.661111111111111 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23992    |399.8666666666667 |6.664444444444444 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23305    |388.4166666666667 |6.473611111111111 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|40971    |682.85            |11.380833333333333|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|38869    |647.8166666666667 |10.796944444444444|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|23395    |389.9166666666667 |6.498611111111111 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|77494    |1291.5666666666666|21.52611111111111 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|24369    |406.15            |6.769166666666667 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|114539   |1908.9833333333333|31.816388888888888|
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|28023    |467.05            |7.784166666666667 |
# |525200031|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|38229    |637.15            |10.619166666666667|
# |525200126|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|317877   |5297.95           |88.29916666666666 |
# |525200335|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |442003   |7366.716666666666 |122.7786111111111 |
# |525200335|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |1093884  |18231.4           |303.8566666666667 |
# |525200924|Tanjung Sekong|Indonesia|Passenger  |Underway Sailing      |97768    |1629.4666666666667|27.157777777777778|
# |525300391|Tanjung Sekong|Indonesia|Passenger  |Under Way Using Engine|27182    |453.03333333333336|7.5505555555555555|
# |563165800|Tanjung Sekong|Singapore|Passenger  |Under Way Using Engine|2577945  |42965.75          |716.0958333333333 |
# +---------+--------------+---------+-----------+----------------------+---------+------------------+------------------+

# %%
# Hitung jumlah outlier per mmsi
outlier_count_mmmsi = outlier_data.groupBy("mmsi").agg(F.count("mmsi").alias("mmsi_outlier"))

# %%
outlier_count_mmmsi = outlier_count_mmmsi.orderBy(col("mmsi_outlier").desc())

# %%
# Tampilkan hasil
outlier_count_mmmsi.show(outlier_count_mmmsi.count(), truncate = False)
# Out:
# +---------+------------+
# |mmsi     |mmsi_outlier|
# +---------+------------+
# |525200031|15          |
# |525015377|15          |
# |525006235|15          |
# |525023144|13          |
# |525119018|13          |
# |525100582|13          |
# |525021421|12          |
# |525019293|11          |
# |525016714|9           |
# |525100336|8           |
# |525100695|7           |
# |525007397|7           |
# |525024295|7           |
# |525019409|6           |
# |525002068|6           |
# |525100633|6           |
# |525100688|6           |
# |525022300|5           |
# |525005232|5           |
# |525019468|5           |
# |525015932|4           |
# |525019408|4           |
# |525002086|4           |
# |525015491|4           |
# |525100375|4           |
# |525004089|4           |
# |525006222|3           |
# |525015375|3           |
# |525100493|3           |
# |525001121|2           |
# |525100777|2           |
# |525200335|2           |
# |525100600|2           |
# |525001068|2           |
# |525019467|2           |
# |525001136|1           |
# |525002087|1           |
# |525002088|1           |
# |525012279|1           |
# |525005177|1           |
# |525015868|1           |
# |525200126|1           |
# |525022100|1           |
# |525200924|1           |
# |525300391|1           |
# |525100805|1           |
# |563165800|1           |
# +---------+------------+

# %%
# Hitung jumlah outlier per status navigasi
outlier_count_nav_stat = outlier_data.groupBy("ns_vessel").agg(F.count("mmsi").alias("ns_vessel_outlier"))

# %%
outlier_count_nav_stat = outlier_count_nav_stat.orderBy(col("ns_vessel_outlier").desc())

# %%
outlier_count_nav_stat.show()
# Out:
# +--------------------+-----------------+
# |           ns_vessel|ns_vessel_outlier|
# +--------------------+-----------------+
# |Under Way Using E...|              176|
# |    Underway Sailing|               45|
# |           At Anchor|               20|
# +--------------------+-----------------+

# %%
# # Membuat box plot berdasarkan Tipe Kapal
# plt.figure(figsize=(10, 6))  # Mengatur ukuran plot

# sns.boxplot(x="vessel_type", y="diff_time_hours", data=diff_time_hours)
# plt.title("Box Plot Durasi di Pelabuhan Berdasarkan Tipe Kapal")
# plt.xlabel("Tipe Kapal")
# plt.ylabel("Durasi (jam)")
# plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca
# plt.show()

# %%
# # Membuat box plot berdasarkan Pelabuhan
# plt.figure(figsize=(10, 6))  # Mengatur ukuran plot

# sns.boxplot(x="Port", y="diff_time_hours", data=diff_time_hours)
# plt.title("Box Plot Durasi di Pelabuhan Berdasarkan Pelabuhan")
# plt.xlabel("Pelabuhan")
# plt.ylabel("Durasi (jam)")
# plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca
# plt.show()

# %%
# # Ambil 20 pelabuhan pertama
# top_20_pelabuhan = diff_time_hours['Port'].value_counts().head(20).index

# # Filter data untuk hanya 20 pelabuhan pertama
# data_top_20 = diff_time_hours[diff_time_hours['Port'].isin(top_20_pelabuhan)]

# # Membuat box plot untuk setiap pelabuhan
# plt.figure(figsize=(12, 8))
# sns.boxplot(x="Port", y="diff_time_hours", data=data_top_20)
# plt.title("Box Plot Durasi di 20 Pelabuhan Pertama")
# plt.xlabel("Nama Pelabuhan")
# plt.ylabel("Durasi (jam)")
# plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca
# plt.show()

# %%
# # Ambil 20 pelabuhan kedua
# top_20_pelabuhan = diff_time_hours['Port'].value_counts().head(40).index[20:]

# # Filter data untuk hanya 20 pelabuhan kedua
# data_top_20 = diff_time_hours[diff_time_hours['Port'].isin(top_20_pelabuhan)]

# # Membuat box plot untuk setiap pelabuhan
# plt.figure(figsize=(12, 8))
# sns.boxplot(x="Port", y="diff_time_hours", data=data_top_20)
# plt.title("Box Plot Durasi di 20 Pelabuhan Kedua")
# plt.xlabel("Nama Pelabuhan")
# plt.ylabel("Durasi (jam)")
# plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca
# plt.show()

# %%
# # Ambil 20 pelabuhan ketiga
# top_20_pelabuhan = diff_time_hours['Port'].value_counts().head(60).index[40:]

# # Filter data untuk hanya 20 pelabuhan ketiga
# data_top_20 = diff_time_hours[diff_time_hours['Port'].isin(top_20_pelabuhan)]

# # Membuat box plot untuk setiap pelabuhan
# plt.figure(figsize=(12, 8))
# sns.boxplot(x="Port", y="diff_time_hours", data=data_top_20)
# plt.title("Box Plot Durasi di 20 Pelabuhan Ketiga")
# plt.xlabel("Nama Pelabuhan")
# plt.ylabel("Durasi (jam)")
# plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca
# plt.show()

# %%
# # Ambil 20 pelabuhan keempat
# top_20_pelabuhan = diff_time_hours['Port'].value_counts().head(80).index[60:]

# # Filter data untuk hanya 20 pelabuhan keempat
# data_top_20 = diff_time_hours[diff_time_hours['Port'].isin(top_20_pelabuhan)]

# # Membuat box plot untuk setiap pelabuhan
# plt.figure(figsize=(12, 8))
# sns.boxplot(x="Port", y="diff_time_hours", data=data_top_20)
# plt.title("Box Plot Durasi di 20 Pelabuhan Keempat")
# plt.xlabel("Nama Pelabuhan")
# plt.ylabel("Durasi (jam)")
# plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca
# plt.show()

# %%
# # Ambil 20 pelabuhan kelima
# top_20_pelabuhan = diff_time_hours['Port'].value_counts().head(100).index[80:]

# # Filter data untuk hanya 20 pelabuhan kelima
# data_top_20 = diff_time_hours[diff_time_hours['Port'].isin(top_20_pelabuhan)]

# # Membuat box plot untuk setiap pelabuhan
# plt.figure(figsize=(12, 8))
# sns.boxplot(x="Port", y="diff_time_hours", data=data_top_20)
# plt.title("Box Plot Durasi di 20 Pelabuhan Kelima")
# plt.xlabel("Nama Pelabuhan")
# plt.ylabel("Durasi (jam)")
# plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca
# plt.show()

# %%
# # Ambil 22 pelabuhan terakhir
# top_20_pelabuhan = diff_time_hours['Port'].value_counts().index[-22:]

# # Filter data untuk hanya 22 pelabuhan terakhir
# data_top_20 = diff_time_hours[diff_time_hours['Port'].isin(top_20_pelabuhan)]

# # Membuat box plot untuk setiap pelabuhan
# plt.figure(figsize=(12, 8))
# sns.boxplot(x="Port", y="diff_time_hours", data=data_top_20)
# plt.title("Box Plot Durasi di 22 Pelabuhan Terakhir")
# plt.xlabel("Nama Pelabuhan")
# plt.ylabel("Durasi (jam)")
# plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca
# plt.show()

# %% [markdown]
# ## Rata-Rata (Detik)

# %%
# Hitung rata-rata waktu di pelabuhan
avg_time_in_port_month = result_diff.withColumn("months", F.date_format("dt_pos_utc", "MMMM")) \
    .groupBy("months").agg(F.avg("diff_time").alias("average_time_in_port"))

# %%
# Tampilkan hasil
avg_time_in_port_month.show()
# Out:
# +--------+--------------------+
# |  months|average_time_in_port|
# +--------+--------------------+
# |February|   4586.785197103781|
# | January|  1704.1452667814115|
# |   March|   8130.640365923385|
# |     May|  3004.4545454545455|
# |   April|   7755.320109439124|
# +--------+--------------------+

# %%
# Hitung rata-rata waktu di pelabuhan menurut tipe kapal
avg_time_in_port_country = result_diff.select("fc_vessel","diff_time").groupBy("fc_vessel").agg(F.avg("diff_time").alias("average_time_in_port"))

# %%
# Tampilkan hasil
avg_time_in_port_country.show(avg_time_in_port_country.count(), truncate = False)
# Out:
# +---------+--------------------+
# |fc_vessel|average_time_in_port|
# +---------+--------------------+
# |Singapore|2577945.0           |
# |Indonesia|4820.325484319812   |
# +---------+--------------------+

# %%
# Hitung rata-rata waktu di pelabuhan menurut tipe kapal
avg_time_in_port_vess_type = result_diff.select("vessel_type","diff_time").groupBy("vessel_type").agg(F.avg("diff_time").alias("average_time_in_port"))

# %%
# Tampilkan hasil
avg_time_in_port_vess_type.show()
# Out:
# +-----------+--------------------+
# |vessel_type|average_time_in_port|
# +-----------+--------------------+
# |  Passenger|   5095.702696917808|
# +-----------+--------------------+

# %% [markdown]
# ## Rata-Rata (Jam)

# %%
# Hitung rata-rata waktu di pelabuhan
avg_time_in_port_month = result_diff.withColumn("months", F.date_format("dt_pos_utc", "MMMM")) \
    .groupBy("months").agg(F.avg("diff_time_hours").alias("average_time_in_port"))

# %%
# Tampilkan hasil
avg_time_in_port_month.show()
# Out:
# +--------+--------------------+
# |  months|average_time_in_port|
# +--------+--------------------+
# |February|  1.2741069991954959|
# | January|  0.4733736852170584|
# |   March|     2.2585112127565|
# |     May|  0.8345707070707071|
# |   April|  2.1542555859553167|
# +--------+--------------------+

# %%
# Hitung rata-rata waktu di pelabuhan menurut tipe kapal
avg_time_in_port_country = result_diff.select("fc_vessel","diff_time_hours").groupBy("fc_vessel").agg(F.avg("diff_time_hours").alias("average_time_in_port"))

# %%
# Tampilkan hasil
avg_time_in_port_country.show(avg_time_in_port_country.count(), truncate = False)
# Out:
# +---------+--------------------+
# |fc_vessel|average_time_in_port|
# +---------+--------------------+
# |Singapore|716.0958333333333   |
# |Indonesia|1.3389793011999414  |
# +---------+--------------------+

# %%
# Hitung rata-rata waktu di pelabuhan menurut tipe kapal
avg_time_in_port_vess_type = result_diff.select("vessel_type","diff_time_hours").groupBy("vessel_type").agg(F.avg("diff_time_hours").alias("average_time_in_port"))

# %%
# Tampilkan hasil
avg_time_in_port_vess_type.show()
# Out:
# +-----------+--------------------+
# |vessel_type|average_time_in_port|
# +-----------+--------------------+
# |  Passenger|  1.4154729713660517|
# +-----------+--------------------+

# %% [markdown]
# ## Rata-Rata (Menit)

# %%
# Hitung rata-rata waktu di pelabuhan
avg_time_in_port_month = result_diff.withColumn("months", F.date_format("dt_pos_utc", "MMMM")) \
    .groupBy("months").agg(F.avg("diff_time_minutes").alias("average_time_in_port"))

# %%
avg_time_in_port_month.show()
# Out:
# +--------+--------------------+
# |  months|average_time_in_port|
# +--------+--------------------+
# |February|   76.44641995172972|
# | January|  28.402421113023525|
# |   March|   135.5106727653897|
# |     May|   50.07424242424243|
# |   April|   129.2553351573187|
# +--------+--------------------+

# %%
# Hitung rata-rata waktu di pelabuhan
avg_time_in_port_day = result_diff.withColumn("day", date_format("dt_pos_utc", "yyyy-MM-dd")) \
    .groupBy("day").agg(F.avg("diff_time_minutes").alias("average_time_in_port"))

# %%
# DataFrame Spark
# rekaman_per_bulan = spark.createDataFrame(rekaman_per_bulan)

# Export ke Pandas DataFrame
avg_time_in_port_day = avg_time_in_port_day.toPandas()

# Download Data
create_download_link(avg_time_in_port_day, title="avg_time_in_port_day", filename="avg_time_in_port_day.csv")
# Out:
# <a download="avg_time_in_port_day.csv" href="data:text/csv;base64,..." target="_blank">avg_time_in_port_day</a>

# %% [markdown]
# ## Median (Detik)

# %%
median_time_in_port_month = result_diff.withColumn("months", F.date_format("dt_pos_utc", "MMMM")) \
    .groupBy("months") \
    .agg(F.expr("percentile_approx(diff_time, 0.5)").alias("median_time_in_port"))

# %%
# Tampilkan hasil
median_time_in_port_month.show()
# Out:
# +--------+-------------------+
# |  months|median_time_in_port|
# +--------+-------------------+
# |February|                651|
# | January|                610|
# |   March|               1653|
# |     May|               1976|
# |   April|               1304|
# +--------+-------------------+

# %%
# Hitung rata-rata waktu di pelabuhan menurut negara kapal
median_time_in_port_country = result_diff.select("fc_vessel","diff_time").groupBy("fc_vessel").agg(F.expr("percentile_approx(diff_time, 0.5)").alias("median_time_in_port"))

# %%
# Tampilkan hasil
median_time_in_port_country.show(median_time_in_port_country.count(), truncate = False)
# Out:
# +---------+-------------------+
# |fc_vessel|median_time_in_port|
# +---------+-------------------+
# |Singapore|2577945            |
# |Indonesia|641                |
# +---------+-------------------+

# %%
# Hitung rata-rata waktu di pelabuhan menurut tipe kapal
median_time_in_port_vess_type = result_diff.select("vessel_type","diff_time").groupBy("vessel_type").agg(F.expr("percentile_approx(diff_time, 0.5)").alias("median_time_in_port"))

# %%
# Tampilkan hasil
median_time_in_port_vess_type.show()
# Out:
# +-----------+-------------------+
# |vessel_type|median_time_in_port|
# +-----------+-------------------+
# |  Passenger|                641|
# +-----------+-------------------+

# %% [markdown]
# ## Median (Jam)

# %%
median_time_in_port_month = result_diff.withColumn("months", F.date_format("dt_pos_utc", "MMMM")) \
    .groupBy("months") \
    .agg(F.expr("percentile_approx(diff_time_hours, 0.5)").alias("median_time_in_port"))

# %%
# Tampilkan hasil
median_time_in_port_month.show()
# Out:
# +--------+-------------------+
# |  months|median_time_in_port|
# +--------+-------------------+
# |February|0.18083333333333335|
# | January|0.16944444444444445|
# |   March|0.45916666666666667|
# |     May| 0.5488888888888889|
# |   April| 0.3622222222222222|
# +--------+-------------------+

# %%
# Hitung rata-rata waktu di pelabuhan menurut negara kapal
median_time_in_port_country = result_diff.select("fc_vessel","diff_time_hours").groupBy("fc_vessel").agg(F.expr("percentile_approx(diff_time_hours, 0.5)").alias("median_time_in_port"))

# %%
# Tampilkan hasil
median_time_in_port_country.show(median_time_in_port_country.count(), truncate = False)
# Out:
# +---------+-------------------+
# |fc_vessel|median_time_in_port|
# +---------+-------------------+
# |Singapore|716.0958333333333  |
# |Indonesia|0.17805555555555555|
# +---------+-------------------+

# %%
# Hitung rata-rata waktu di pelabuhan menurut tipe kapal
median_time_in_port_vess_type = result_diff.select("vessel_type","diff_time_hours").groupBy("vessel_type").agg(F.expr("percentile_approx(diff_time_hours, 0.5)").alias("median_time_in_port"))

# %%
# Tampilkan hasil
median_time_in_port_vess_type.show()
# Out:
# +-----------+-------------------+
# |vessel_type|median_time_in_port|
# +-----------+-------------------+
# |  Passenger|0.17805555555555555|
# +-----------+-------------------+

# %% [markdown]
# ## Median (Menit)

# %%
median_time_in_port_month = result_diff.withColumn("months", F.date_format("dt_pos_utc", "MMMM")) \
    .groupBy("months") \
    .agg(F.expr("percentile_approx(diff_time_minutes, 0.5)").alias("median_time_in_port"))

# %%
median_time_in_port_month.show()
# Out:
# +--------+-------------------+
# |  months|median_time_in_port|
# +--------+-------------------+
# |February|              10.85|
# | January| 10.166666666666666|
# |   March|              27.55|
# |     May|  32.93333333333333|
# |   April| 21.733333333333334|
# +--------+-------------------+

# %%
median_time_in_port_day = result_diff.withColumn("day", date_format("dt_pos_utc", "yyyy-MM-dd")) \
    .groupBy("day") \
    .agg(F.expr("percentile_approx(diff_time_minutes, 0.5)").alias("median_time_in_port"))

# %%
# DataFrame Spark
# rekaman_per_bulan = spark.createDataFrame(rekaman_per_bulan)

# Export ke Pandas DataFrame
median_time_in_port_day = median_time_in_port_day.toPandas()

# Download Data
create_download_link(median_time_in_port_day, title="median_time_in_port_day", filename="median_time_in_port_day.csv")
# Out:
# <a download="median_time_in_port_day.csv" href="data:text/csv;base64,..." target="_blank">median_time_in_port_day</a>

# %%
spark.stop()
