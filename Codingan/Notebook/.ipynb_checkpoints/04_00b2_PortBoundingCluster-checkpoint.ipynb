# %% [markdown]
# # Initialialize

# %%
from sedona.register import SedonaRegistrator
SedonaRegistrator.registerAll(spark)
# Out:
# True

# %%
import subprocess
import sys

# %%
GITLAB_USER = "read aistt"
GITLAB_TOKEN = "J1KkstArfyXB6dZvFchN"
git_package = f"git+https://(GITLAB_USER):(GITLAB_TOKEN)@code.officialstatistics.org/trade-task-team-phase-1/ais.git"
std_out = subprocess.run([sys.executable, "-m", "pip", "install", git_package], capture_output=True, text=True) .stdout
print(std_out)
# Out:
# Collecting git+https://%28GITLAB_USER%29:****@code.officialstatistics.org/trade-task-team-phase-1/ais.git
#   Cloning https://%28GITLAB_USER%29:****@code.officialstatistics.org/trade-task-team-phase-1/ais.git to /tmp/pip-req-build-acfp4qbx

# %%
GITLAB_USER = 'ml_group_read_only'
GITLAB_TOKEN = 'eac7ZwiseRdeLwmBsrsm'

# Main: for using from current issued version
git_package = f"git+https://{GITLAB_USER}:{GITLAB_TOKEN}@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git"

std_out = subprocess.run([sys.executable, "-m", "pip", "install",git_package], capture_output=True, text=True).stdout
print(std_out)
# Out:
# Collecting git+https://ml_group_read_only:****@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git
#   Cloning https://ml_group_read_only:****@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git to /tmp/pip-req-build-tif560sb
#   Resolved https://ml_group_read_only:****@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git to commit 89f1aab64fee28c2f86e86d6fa7b55118882b1e8
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: unece-ais
#   Building wheel for unece-ais (setup.py): started
#   Building wheel for unece-ais (setup.py): finished with status 'done'
#   Created wheel for unece-ais: filename=unece_ais-0.0.4-py3-none-any.whl size=12493 sha256=4e3d0680465ab69d9227be806c1081eebe0ce6d6ce3ce3535edf16bd49312ea3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pvzfyusj/wheels/61/b5/f9/bcf024b104169c32950c03a4605d2d07ea9da07cae7bed5e3e
# Successfully built unece-ais
# Installing collected packages: unece-ais
# Successfully installed unece-ais-0.0.4

# %%
from pyspark.sql import functions as F
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, date_format, count, countDistinct, when, expr, unix_timestamp
from pyspark.sql.functions import year, month, dayofmonth, hour, minute, second
from pyspark.sql.functions import monotonically_increasing_id, lead, lag, abs, row_number
from pyspark.sql.functions import concat_ws, split, lit, min, max
from pyspark.sql.types import IntegerType, StringType, StructType, StructField, ArrayType, LongType, FloatType
from pyspark.sql.window import Window

from shapely.geometry import Point, Polygon, mapping, MultiPolygon
from IPython.display import HTML
from ais import functions as af
from unece_ais import unece_ais as un
from multiprocessing import Pool
from shapely.ops import unary_union

# %%
import h3.api.numpy_int as h3int
import matplotlib.pyplot as plt
import geopandas as gpd
import seaborn as sns
import pandas as pd
import numpy as np
import calendar
import base64
import folium
import tqdm
import h3
# Out:
# generated new fontManager

# %%
import h3.api.numpy_int as h3int
from sklearn.cluster import DBSCAN
from pyproj import Transformer

# %%
pd.set_option('display.max_columns', None) #Show all columns in pandas df
pd.set_option('display.max_rows', 100) #Show 100 rows in pandas df
pd.options.display.float_format = '{:.10f}'.format #Show float with 10 decimal points in pandas df

from IPython.core.interactiveshell import InteractiveShell #allow multiple outputs in one jupyter cell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Path
base_path = "s3a://ungp-ais-data-historical-backup/user_temp/"
path_unique = base_path + "222011349/"

# %% [markdown]
# # Data

# %% [markdown]
# ## AOI Indonesia

# %%
# Read Data
aoi_indo = spark.read.parquet(path_unique + "data-ais-preparation-for-cluster-bounding-indonesia.parquet", header=True)

# %% [markdown]
# ## AOI LN

# %%
# Read Data
aoi_ln = spark.read.parquet(path_unique + "data-ais-preparation-for-cluster-bounding-luar-negeri.parquet", header=True)

# %% [markdown]
# ## Port Indonesia

# %%
# Read Data
port_aoi = spark.read.parquet(path_unique + "ports_indonesia.parquet", header=True)

# %%
#explode data port
port_aoi_exploded = port_aoi.select("Port", F.explode("boundary_h3").alias("boundary_h3"))

# %% [markdown]
# ## Port LN

# %%
# Read Data
port_aoi_ln = spark.read.parquet(path_unique + "ports_luarnegeri.parquet", header=True)

# %%
#explode data port
port_aoi_ln_exploded = port_aoi_ln.select("Port", "Country", F.explode("boundary_h3").alias("boundary_h3"))

# %% [markdown]
# # Function

# %%
def get_parameters(df, cluster_res, per):
    eps_m = round(h3int.edge_length(cluster_res) * 1000)
    df["h3_cluster_index"] = df["H3_int_index_8"] \
    .apply(lambda x: h3int.h3_to_parent(x, cluster_res))
    
    df_cluster = df.groupby("h3_cluster_index")["count_mmsi"].sum() \
    .reset_index() \
    .sort_values("count_mmsi",ignore_index=True, ascending=False)
    df_cluster["cumsum"] = df_cluster["count_mmsi"].cumsum()
    tot = df_cluster.count_mmsi.sum()
    df_cluster["cumper"] = df_cluster["cumsum"] / tot
    
    min_points = df_cluster[df_cluster.cumper >= per].iloc[0].count_mmsi
    return eps_m, int(min_points)

# %% [markdown]
# # Indonesia

# %%
sdf_agg = aoi_indo.filter(
    (F.col("position") == "in port") & (F.col("stationary") == "Y")) \
.groupBy("H3_int_index_8") \
.agg(F.count("mmsi").alias("count_mmsi"))

# %%
df = sdf_agg.toPandas()
eps_m, min_points = get_parameters(df, 
                                   cluster_res = 8,
                                   per = 0.90)
model = DBSCAN(eps=eps_m,min_samples=min_points)

# %%
points = df["H3_int_index_8"].apply(lambda x: h3int.h3_to_geo(x))
df["latitude"], df["longitude"] = zip(*points)

transf = Transformer.from_crs(4326, 3832, always_xy=True)

df["long_t"], df["lat_t"] = transf.transform(df["longitude"].values, df["latitude"].values)

# %%
# Cetak beberapa baris pertama untuk memastikan kolom latitude dan longitude dibuat
print(df[['latitude', 'longitude']].head())
# Out:
#       latitude      longitude
# 0 1.2641530663 103.9724784050
# 1 1.2491865310 103.8689182147
# 2 1.2800830522 103.9651783456
# 3 1.0940667878 103.8891206405
# 4 1.3068364241 104.1142299349

# %%
# Cetak beberapa baris pertama untuk memastikan kolom long_t dan lat_t dibuat
print(df[['long_t', 'lat_t']].head())
# Out:
#                long_t             lat_t
# 0 -5123760.2664301442 139794.3042009453
# 1 -5135288.5340867089 138138.9869276356
# 2 -5124572.9053304195 141556.1909269948
# 3 -5133039.6103260666 120983.0935846553
# 4 -5107980.5583008863 144515.1897363407

# %%
# Melakukan fitting model dengan data yang telah ditransformasi
X = df[["long_t", "lat_t"]].values
sample_weight = df["count_mmsi"].values
model_fit = model.fit(X, sample_weight=sample_weight)

# %%
# Menambahkan hasil klaster ke DataFrame
df['cluster'] = model_fit.labels_

# %%
# Menampilkan nama-nama kolom dalam DataFrame
print(df.columns)
# Out:
# Index(['H3_int_index_8', 'count_mmsi', 'h3_cluster_index', 'latitude',
#        'longitude', 'long_t', 'lat_t', 'cluster'],
#       dtype='object')

# %%
# Mengonversi DataFrame PySpark ke Pandas DataFrame
port_aoi_exploded_pandas = port_aoi_exploded.toPandas()

# %%
# Menggabungkan informasi pelabuhan dengan klaster
df = df.merge(port_aoi_exploded_pandas, left_on='H3_int_index_8', right_on='boundary_h3', how='left')

# %%
# Menampilkan nama-nama kolom dalam DataFrame
print(df.columns)
# Out:
# Index(['H3_int_index_8', 'count_mmsi', 'h3_cluster_index', 'latitude',
#        'longitude', 'long_t', 'lat_t', 'cluster', 'Port', 'boundary_h3'],
#       dtype='object')

# %%
# Menampilkan DataFrame
df
# Out:
#            H3_int_index_8  count_mmsi    h3_cluster_index     latitude  \
# 0      614269018185924607        1746  614269018185924607 1.2641530663
# 1      614269018185924607        1746  614269018185924607 1.2641530663
# 2      614268618009477119      117846  614268618009477119 1.2491865310
# 3      614268618009477119      117846  614268618009477119 1.2491865310
# 4      614269018401931263      207890  614269018401931263 1.2800830522
# ...                   ...         ...                 ...          ...
# 10328  614269020511666175           3  614269020511666175 0.9765927564
# 10329  614269020511666175           3  614269020511666175 0.9765927564
# 10330  614269020511666175           3  614269020511666175 0.9765927564
# 10331  614268617697001471           2  614268617697001471 1.2512461614
# 10332  614268617697001471           2  614268617697001471 1.2512461614
#
#            longitude              long_t             lat_t  cluster  \
# 0     103.9724784050 -5123760.2664301442 139794.3042009453       -1
# 1     103.9724784050 -5123760.2664301442 139794.3042009453       -1
# 2     103.8689182147 -5135288.5340867089 138138.9869276356        0
# 3     103.8689182147 -5135288.5340867089 138138.9869276356        0
# 4     103.9651783456 -5124572.9053304195 141556.1909269948        1
# ...              ...                 ...               ...      ...
# 10328 104.0194055968 -5118536.3553406736 107991.3359559891       -1
# 10329 104.0194055968 -5118536.3553406736 107991.3359559891       -1
# 10330 104.0194055968 -5118536.3553406736 107991.3359559891       -1
# 10331 103.8424834827 -5138231.2349838614 138366.7840290953       -1
# 10332 103.8424834827 -5138231.2349838614 138366.7840290953       -1
#
#               Port         boundary_h3
# 0      Pulau Sambu  614269018185924607
# 1         Sekupang  614269018185924607
# 2      Pulau Sambu  614268618009477119
# 3         Sekupang  614268618009477119
# 4      Pulau Sambu  614269018401931263
# ...            ...                 ...
# 10328  Pulau Sambu  614269020511666175
# 10329  Tanjunguban  614269020511666175
# 10330     Sekupang  614269020511666175
# 10331  Pulau Sambu  614268617697001471
# 10332     Sekupang  614268617697001471
#
# [10333 rows x 10 columns]

# %%
# Fungsi untuk menghasilkan poligon dari H3 indices
def generate_polygon_from_h3_indices(h3_indices):
    polygons = []
    for h3_index in h3_indices:
        h3_index_str = h3.h3_to_string(h3_index)  # Konversi h3_index ke string
        geo_boundary = h3.h3_to_geo_boundary(h3_index_str, geo_json=True)
        polygons.append(Polygon(geo_boundary))
    if polygons:
        return unary_union(polygons)  # Menggabungkan semua poligon menjadi satu
    else:
        return None

# %%
# Membuat DataFrame kosong untuk menyimpan data poligon pelabuhan
port_polygon_df = pd.DataFrame(columns=['Port', 'Polygon'])

# Menggambar poligon untuk setiap pelabuhan
for port_name, group in df.groupby('Port'):
    # Mengumpulkan H3 indices terkait dengan pelabuhan ini
    h3_indices = group['H3_int_index_8'].unique()
    
    # Menghasilkan poligon dari H3 indices yang terkait dengan pelabuhan ini
    cluster_polygon = generate_polygon_from_h3_indices(h3_indices)
    if cluster_polygon:
        # Menambahkan data poligon pelabuhan ke dalam DataFrame baru
        port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# Out:
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)
# /tmp/ipykernel_51/826935652.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df = port_polygon_df.append({'Port': port_name, 'Polygon': cluster_polygon}, ignore_index=True)

# %%
# Menampilkan DataFrame yang berisi data poligon pelabuhan
port_polygon_df
# Out:
#                        Port                                            Polygon
# 0                 Amamapare  MULTIPOLYGON (((136.78835373358896 -4.86372174...
# 1                     Ambon  MULTIPOLYGON (((128.03059176099492 -3.82580815...
# 2                   Ampenan  MULTIPOLYGON (((115.92689887993072 -8.76558425...
# 3                 Anyer Lor  MULTIPOLYGON (((105.73101561576426 -6.23952524...
# 4         Ardjuna Oil Field  MULTIPOLYGON (((107.61107013543578 -6.06848519...
# ..                      ...                                                ...
# 112                   Tuban  MULTIPOLYGON (((111.95362043688205 -6.75910381...
# 113           Ujung Pandang  MULTIPOLYGON (((119.25629393428245 -5.32355897...
# 114               Uleelheue  MULTIPOLYGON (((95.23862219385613 5.4410147885...
# 115                Waingapu  POLYGON ((120.25831067992627 -9.64371919144613...
# 116  Widuri Marine Terminal  MULTIPOLYGON (((106.46074228330399 -4.83657468...
#
# [117 rows x 2 columns]

# %%
# Membuat DataFrame baru yang berisi nama pelabuhan dan daftar H3 index
port_h3_df = df.groupby('Port')['h3_cluster_index'].apply(list).reset_index()

# %%
port_h3_df
# Out:
#                        Port                                   h3_cluster_index
# 0                 Amamapare  [614505849322209279, 614505893037342719, 61450...
# 1                     Ambon  [615115291577286655, 615115291558412287, 61511...
# 2                   Ampenan  [615122069220229119, 615122068658192383, 61512...
# 3                 Anyer Lor  [614953762787688447, 614953806590902271, 61495...
# 4         Ardjuna Oil Field  [614953996292980735, 614953997450608639, 61495...
# ..                      ...                                                ...
# 112                   Tuban  [614979089643601919, 614978854840172543, 61497...
# 113           Ujung Pandang  [615110826015064063, 615110819740385279, 61511...
# 114               Uleelheue  [614272118628024319, 614272118636412927, 61427...
# 115                Waingapu  [615112604242673663, 615112604276228095, 61511...
# 116  Widuri Marine Terminal  [614964281741410303, 614964275412205567, 61496...
#
# [117 rows x 2 columns]

# %%
port_h3_df_w = port_h3_df[port_h3_df['Port']=="Amamapare"]

# %%
# Menghasilkan peta
r = folium.Map(location=[2, 120], zoom_start=4.2, tiles="CartoDB positron")

# Menggambar poligon untuk setiap pelabuhan
for index, row in port_polygon_df.iterrows():
    port_name = row['Port']
    polygon = row['Polygon']

    # Mengonversi poligon ke format GeoJSON
    geo_json = polygon.__geo_interface__

    # Menambahkan poligon ke peta
    folium.GeoJson(data=geo_json, name=port_name, style_function=lambda x: {"fillColor": "blue"}).add_to(r)

# %%
# Menyimpan dan Menampilkan Peta
r.save('port_polygons_map.html')
r
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8a63a33de37410ecb3d41dc6c2f0bd7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8a63a33de37410ecb3d41dc6c2f0bd7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8a63a33de37410ecb3d41dc6c2f0bd7 = L.map(
#                 &quot;map_d8a63a33de37410ecb3d41dc6c2f0bd7&quot;,
#                 {
#                     center: [2.0, 120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_574282d89d616abc7eb8c4467273bcbe = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8a63a33de37410ecb3d41dc6c2f0bd7);
#
#
#         function geo_json_953fd32034972df62f9524488d246593_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;blue&quot;};
#             }
#         }
#
#         function geo_json_953fd32034972df62f9524488d246593_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_953fd32034972df62f9524488d246593 = L.geoJson(null, {
#                 onEachFeature: geo_json_953fd32034972df62f9524488d246593_onEachFeature,
#
#                 style: geo_json_953fd32034972df62f9524488d246593_styler,
#         });
#
#         function geo_json_953fd32034972df62f9524488d246593_add (data) {
#             geo_json_953fd32034972df62f9524488d246593
#                 .addData(data)
#                 .addTo(map_d8a63a33de37410ecb3d41dc6c2f0bd7);
#         }
#             geo_json_953fd32034972df62f9524488d246593_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[136.78835373358896, -4.863721748636297], [136.78923105540267, -4.858676592312336], [136.7852234508471, -4.855391917057727], [136.7861007587543, -4.8503465253242295], [136.79098573796313, -4.848585825862163], [136.7918630987096, -4.843540215885947], [136.79674815926361, -4.841779390195954], [136.7976255728339, -4.836733562175796], [136.80251071463667, -4.834972610432147], [136.8065184045444, -4.8382575614792085], [136.80564092428995, -4.843303372352883], [136.80964856196871, -4.8465881630257295], [136.80877106784445, -4.851633738710003], [136.80388600269882, -4.853394540937083], [136.8030085613624, -4.858439898497565], [136.79812357735534, -4.860200574503057], [136.79724618882227, -4.86524571374101], [136.79236128605018, -4.867006263350677], [136.78835373358896, -4.863721748636297]]], [[[136.76743841962352, -4.85234345606071], [136.76831559393355, -4.8472980306258195], [136.7643078908054, -4.84401305860786], [136.76518505117045, -4.838967398078154], [136.7700699815098, -4.837206726288925], [136.77094719477586, -4.832160847536958], [136.76693941086094, -4.828875623888779], [136.76781661018617, -4.8238295103791895], [136.7638087743349, -4.820544127140113], [136.7646859597133, -4.815497779070842], [136.76957104779595, -4.813736830905524], [136.77044828608024, -4.80869026509161], [136.76644036943358, -4.8054046308152465], [136.76731759377526, -4.800357830779135], [136.7722028016071, -4.798596681685151], [136.77308007884938, -4.7935496642428586], [136.7779653683569, -4.791788389425029], [136.78197334252434, -4.7950742069225445], [136.78109599847474, -4.800121207628888], [136.77621074705453, -4.80188240758439], [136.77533345587986, -4.806929190944016], [136.7793413493238, -4.8102147575643635], [136.77846404422272, -4.8152613066432375], [136.78247188564055, -4.818546713783556], [136.78159456661908, -4.823593028383648], [136.77670947296983, -4.825353952647722], [136.7758322068183, -4.830400049423171], [136.77983996752127, -4.833685205093172], [136.77896268744516, -4.838731067052476], [136.77407771346574, -4.840491790145171], [136.77320048626495, -4.845537433941636], [136.77720816623923, -4.848822337804973], [136.77633092510965, -4.853867746448121], [136.77144607081487, -4.855628268030406], [136.76743841962352, -4.85234345606071]]], [[[136.7685730823821, -4.766787578619722], [136.76945037070675, -4.761739643330395], [136.77433585604894, -4.75997801861021], [136.77834401499956, -4.763264403977411], [136.7774666598446, -4.768312322647094], [136.77258121255886, -4.770073872579938], [136.7685730823821, -4.766787578619722]]], [[[136.81140358913018, -4.836496558532065], [136.81228112216715, -4.831450529872753], [136.80827340397036, -4.828165486943897], [136.8091509231417, -4.8231192234323945], [136.81403622715283, -4.821358020104475], [136.81804397355776, -4.824643154890586], [136.822929320049, -4.822881900539885], [136.8269370422177, -4.826166966950643], [136.8318224309538, -4.82440566

# %% [markdown]
# # Luar Negeri

# %%
sdf_agg_ln = aoi_ln.filter(
    (F.col("position") == "in port") & (F.col("stationary") == "Y")) \
.groupBy("H3_int_index_8") \
.agg(F.count("mmsi").alias("count_mmsi"))

# %%
df_ln = sdf_agg_ln.toPandas()
eps_m_ln, min_points_ln = get_parameters(df_ln, 
                                   cluster_res = 8,
                                   per = 0.90)
model_ln = DBSCAN(eps=eps_m_ln,min_samples=min_points_ln)

# %%
points_ln = df_ln["H3_int_index_8"].apply(lambda x: h3int.h3_to_geo(x))
df_ln["latitude"], df_ln["longitude"] = zip(*points_ln)

transf_ln = Transformer.from_crs(4326, 3832, always_xy=True)
(df_ln["long_t"], df_ln["lat_t"]) = transf_ln.transform(df_ln["longitude"].values,
                                               df_ln["latitude"].values)

# %%
X_ln = df_ln[["long_t", "lat_t"]].values
sample_weight_ln = df_ln["count_mmsi"].values
model_fit_ln = model.fit(X_ln, sample_weight=sample_weight_ln)

# %%
# Menambahkan hasil klaster ke DataFrame
df_ln['cluster'] = model_fit_ln.labels_

# %%
# Mengonversi DataFrame PySpark ke Pandas DataFrame
port_aoi_ln_exploded_pandas = port_aoi_ln_exploded.toPandas()

# %%
# Menggabungkan informasi pelabuhan dengan klaster
df_ln = df_ln.merge(port_aoi_ln_exploded_pandas, left_on='H3_int_index_8', right_on='boundary_h3', how='left')

# %%
# Menampilkan DataFrame
df_ln
# Out:
#             H3_int_index_8  count_mmsi    h3_cluster_index       latitude  \
# 0       614268610952560639      396120  614268610952560639   1.2941112070
# 1       614268610952560639      396120  614268610952560639   1.2941112070
# 2       614268610952560639      396120  614268610952560639   1.2941112070
# 3       614268610952560639      396120  614268610952560639   1.2941112070
# 4       614268610952560639      396120  614268610952560639   1.2941112070
# ...                    ...         ...                 ...            ...
# 138309  614266824067907583           3  614266824067907583   4.2572773701
# 138310  613031138885107711         144  613031138885107711  40.6959976127
# 138311  613031138885107711         144  613031138885107711  40.6959976127
# 138312  614268358543540223          19  614268358543540223   5.5523050249
# 138313  616034821547753471         329  616034821547753471 -35.0016544945
#
#             longitude               long_t               lat_t  cluster  \
# 0      103.6867913970  -5155562.7986917663   143107.7406976691        0
# 1      103.6867913970  -5155562.7986917663   143107.7406976691        0
# 2      103.6867913970  -5155562.7986917663   143107.7406976691        0
# 3      103.6867913970  -5155562.7986917663   143107.7406976691        0
# 4      103.6867913970  -5155562.7986917663   143107.7406976691        0
# ...               ...                  ...                 ...      ...
# 138309 103.5159549518  -5174580.2247732347   471184.9289614311       -1
# 138310  29.4033350761 -13424759.3306953758  4939736.9817814836       -1
# 138311  29.4033350761 -13424759.3306953758  4939736.9817814836       -1
# 138312 100.1860495470  -5545263.5988290934   614918.1457385385       -1
# 138313 118.0857100711  -3552682.5039101881 -4139596.5915193888       -1
#
#                              Port    Country         boundary_h3
# 0                     Pulau Bukom  Singapore  614268610952560639
# 1       Keppel - (East Singapore)  Singapore  614268610952560639
# 2                   Jurong Island  Singapore  614268610952560639
# 3                   Pulau Sebarok  Singapore  614268610952560639
# 4                 Tanjung Pelepas   Malaysia  614268610952560639
# ...                           ...        ...                 ...
# 138309             Kemaman Harbor   Malaysia  614266824067907583
# 138310                      Gebze     Turkey  613031138885107711
# 138311                 Kaba Burnu     Turkey  613031138885107711
# 138312               Pulau Pinang   Malaysia  614268358543540223
# 138313                     Albany  Australia  616034821547753471
#
# [138314 rows x 11 columns]

# %%
# Fungsi untuk menghasilkan poligon dari H3 indices
def generate_polygon_from_h3_indices(h3_indices):
    polygons = []
    for h3_index in h3_indices:
        h3_index_str = h3.h3_to_string(h3_index)  # Konversi h3_index ke string
        geo_boundary = h3.h3_to_geo_boundary(h3_index_str, geo_json=True)
        polygons.append(Polygon(geo_boundary))
    if polygons:
        return unary_union(polygons)  # Menggabungkan semua poligon menjadi satu
    else:
        return None

# %%
# Membuat DataFrame kosong untuk menyimpan data poligon pelabuhan
port_polygon_df_ln = pd.DataFrame(columns=['Port', 'Country', 'Polygon'])

# Menggambar poligon untuk setiap pelabuhan
for port_name, group in df_ln.groupby('Port'):
    # Mengumpulkan H3 indices terkait dengan pelabuhan ini
    h3_indices = group['H3_int_index_8'].unique()
    
    # Menghasilkan poligon dari H3 indices yang terkait dengan pelabuhan ini
    cluster_polygon = generate_polygon_from_h3_indices(h3_indices)
    
    if cluster_polygon:
        # Menentukan nilai untuk 'Country' (misalnya mengambil nilai pertama)
        country_name = group['Country'].iloc[0] if 'Country' in group.columns else 'Unknown'
        
        # Menambahkan data poligon pelabuhan ke dalam DataFrame baru
        port_polygon_df_ln = port_polygon_df_ln.append({
            'Port': port_name, 
            'Country': country_name, 
            'Polygon': cluster_polygon
        }, ignore_index=True)
# Out:
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# ...
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({
# /tmp/ipykernel_51/3867308583.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   port_polygon_df_ln = port_polygon_df_ln.append({

# %%
# Menampilkan DataFrame yang berisi data poligon pelabuhan
port_polygon_df_ln
# Out:
#                   Port               Country  \
# 0               Abadan                  Iran
# 1          Abashiri Ko                 Japan
# 2               Abenra               Denmark
# 3             Aberdeen         United States
# 4              Abidjan         Cote D'Ivoire
# ...                ...                   ...
# 2669          Zhoushan                 China
# 2670            Zhuhai                 China
# 2671            Zirkuh  United Arab Emirates
# 2672  Zirkuh Oil Field  United Arab Emirates
# 2673         Zonguldak                Turkey
#
#                                                 Polygon
# 0     MULTIPOLYGON (((48.18027770385484 30.353623850...
# 1     POLYGON ((144.29093279836795 44.00979010527794...
# 2     MULTIPOLYGON (((9.451007979984466 55.019990297...
# 3     MULTIPOLYGON (((-124.10620420731645 46.9173590...
# 4     MULTIPOLYGON (((-4.104065661281831 5.170860780...
# ...                                                 ...
# 2669  MULTIPOLYGON (((121.93087131402007 29.91737973...
# 2670  MULTIPOLYGON (((113.71936966345699 22.04790563...
# 2671  MULTIPOLYGON (((52.94931604584301 24.994259559...
# 2672  MULTIPOLYGON (((52.946149081069095 24.99108026...
# 2673  MULTIPOLYGON (((31.67395015597951 41.415551739...
#
# [2674 rows x 3 columns]

# %%
# Membuat DataFrame baru yang berisi nama pelabuhan, negara, dan daftar H3 index
port_h3_df_ln = df_ln.groupby(['Port', 'Country'])['h3_cluster_index'].apply(list).reset_index()

# %%
port_h3_df_ln
# Out:
#                   Port               Country  \
# 0               Abadan                  Iran
# 1          Abashiri Ko                 Japan
# 2               Abenra               Denmark
# 3             Aberdeen        United Kingdom
# 4             Aberdeen         United States
# ...                ...                   ...
# 2708          Zhoushan                 China
# 2709            Zhuhai                 China
# 2710            Zirkuh  United Arab Emirates
# 2711  Zirkuh Oil Field  United Arab Emirates
# 2712         Zonguldak                Turkey
#
#                                        h3_cluster_index
# 0     [613274347731156991, 613274349585039359, 61327...
# 1                                  [613310697792602111]
# 2     [613038275749216255, 613038275778576383, 61303...
# 3     [612937498709983231, 612937498814840831, 61293...
# 4     [613206846278205439, 613206843224752127, 61320...
# ...                                                 ...
# 2708  [613812607976996863, 613812611282108415, 61381...
# 2709  [613633274157203455, 613633275260305407, 61363...
# 2710  [613679541107294207, 613679538840272895, 61367...
# 2711  [613679541107294207, 613679541103099903, 61367...
# 2712  [613283560014479359, 613283561513943039, 61328...
#
# [2713 rows x 3 columns]

# %%
# Menghasilkan peta
s = folium.Map(location=[2, 120], zoom_start=4.2, tiles="CartoDB positron")

# Menggambar poligon untuk setiap pelabuhan
for index, row in port_polygon_df_ln.iterrows():
    port_name = row['Port']
    polygon = row['Polygon']

    # Mengonversi poligon ke format GeoJSON
    geo_json = polygon.__geo_interface__

    # Menambahkan poligon ke peta
    folium.GeoJson(data=geo_json, name=port_name, style_function=lambda x: {"fillColor": "blue"}).add_to(s)

# %%
# Menyimpan dan Menampilkan Peta
s.save('port_polygons_ln_map.html')
s

# %% [markdown]
# # Save Data

# %% [markdown]
# ## Indonesia

# %%
port_h3_trans = port_h3_df

# %%
# Mengubah tipe data kolom boundary_h3 dari object ke array long
port_h3_trans.loc[:, 'h3_cluster_index'] = port_h3_trans['h3_cluster_index'].apply(lambda arr: [int(x) for x in arr])

# %%
# Mendefinisikan skema Spark
schema = StructType([
    StructField("Port", StringType(), True),
    StructField("h3_cluster_index", ArrayType(LongType()), True)
])

# Membuat DataFrame Spark
port_h3_df_spark = spark.createDataFrame(port_h3_trans, schema=schema)
# Out:
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
# cek
port_h3_df_spark.printSchema()
# Out:
# root
#  |-- Port: string (nullable = true)
#  |-- h3_cluster_index: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
# Save
port_h3_df_spark.write.option("header", True).mode("overwrite").parquet(path_unique + "ports_indonesia_v2.parquet")

# %% [markdown]
# ## Luar Negeri

# %%
port_h3_trans_ln = port_h3_df_ln

# %%
# Mengubah tipe data kolom boundary_h3 dari object ke array long
port_h3_trans_ln.loc[:, 'h3_cluster_index'] = port_h3_trans_ln['h3_cluster_index'].apply(lambda arr: [int(x) for x in arr])

# %%
# Mendefinisikan skema Spark
schema = StructType([
    StructField("Port", StringType(), True),
    StructField("Country", StringType(), True),
    StructField("h3_cluster_index", ArrayType(LongType()), True)
])

# Membuat DataFrame Spark
port_h3_df_ln_spark = spark.createDataFrame(port_h3_trans_ln, schema=schema)

# %%
# cek
port_h3_df_ln_spark.printSchema()
# Out:
# root
#  |-- Port: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- h3_cluster_index: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
# Save
port_h3_df_ln_spark.write.option("header", True).mode("overwrite").parquet(path_unique + "ports_luarnegeri_v2.parquet")

# %% [markdown]
# ## Amamapare

# %%
port_h3_df_w_trans = port_h3_df_w

# %%
# Mengubah tipe data kolom boundary_h3 dari object ke array long
port_h3_df_w_trans.loc[:, 'h3_cluster_index'] = port_h3_df_w_trans['h3_cluster_index'].apply(lambda arr: [int(x) for x in arr])

# %%
# Mendefinisikan skema Spark
schema = StructType([
    StructField("Port", StringType(), True),
    StructField("h3_cluster_index", ArrayType(LongType()), True)
])

# Membuat DataFrame Spark
port_h3_df_w_spark = spark.createDataFrame(port_h3_df_w_trans, schema=schema)

# %%
# Save
port_h3_df_w_spark.write.option("header", True).mode("overwrite").parquet(path_unique + "port_amamapare_v2.parquet")

# %%
spark.stop()
