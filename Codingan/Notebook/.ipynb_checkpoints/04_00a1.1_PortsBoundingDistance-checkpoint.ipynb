# %% [markdown]
# # Initialize

# %%
import sys
import subprocess

# %%
# pip install h3-py
import h3
# pip install geodatasets
# std_out = subprocess.run([sys.executable, "-m", "pip", "install", git_package], capture_output=True, text=True) .stdout
# print(std_out)

# %%
GITLAB_USER = "read aistt"
GITLAB_TOKEN = "J1KkstArfyXB6dZvFchN"
git_package = f"git+https://(GITLAB_USER):(GITLAB_TOKEN)@code.officialstatistics.org/trade-task-team-phase-1/ais.git"
std_out = subprocess.run([sys.executable, "-m", "pip", "install", git_package], capture_output=True, text=True) .stdout
print(std_out)
# Out:
# Collecting git+https://%28GITLAB_USER%29:****@code.officialstatistics.org/trade-task-team-phase-1/ais.git
#   Cloning https://%28GITLAB_USER%29:****@code.officialstatistics.org/trade-task-team-phase-1/ais.git to /tmp/pip-req-build-89zt7dly

# %%
GITLAB_USER = 'ml_group_read_only'
GITLAB_TOKEN = 'eac7ZwiseRdeLwmBsrsm'

# Main: for using from current issued version
git_package = f"git+https://{GITLAB_USER}:{GITLAB_TOKEN}@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git"

std_out = subprocess.run([sys.executable, "-m", "pip", "install",git_package], capture_output=True, text=True).stdout
print(std_out)
# Out:
# Collecting git+https://ml_group_read_only:****@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git
#   Cloning https://ml_group_read_only:****@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git to /tmp/pip-req-build-kir8jgo5
#   Resolved https://ml_group_read_only:****@code.officialstatistics.org/mlpolygonsalgorithm/ml-group-polygons.git to commit 89f1aab64fee28c2f86e86d6fa7b55118882b1e8
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: unece-ais
#   Building wheel for unece-ais (setup.py): started
#   Building wheel for unece-ais (setup.py): finished with status 'done'
#   Created wheel for unece-ais: filename=unece_ais-0.0.4-py3-none-any.whl size=12493 sha256=375d9590b636a403fcf9fe5c5b727aea075a18e9a5625dc8d929c4c17ed9e44f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pry7h7yv/wheels/61/b5/f9/bcf024b104169c32950c03a4605d2d07ea9da07cae7bed5e3e
# Successfully built unece-ais
# Installing collected packages: unece-ais
# Successfully installed unece-ais-0.0.4

# %%
#For 3.3.1
#Register Sedona Functions to Spark
from sedona.register import SedonaRegistrator
SedonaRegistrator.registerAll(spark)
# Out:
# True

# %%
from pyspark.sql import SparkSession
from ais import functions as af
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, ArrayType, LongType, FloatType
from pyspark.sql.functions import col, pandas_udf
from unece_ais import unece_ais as un

# %%
import h3.api.numpy_int as h3int
from shapely.geometry import mapping, Polygon, Point, LineString, MultiPolygon
from shapely import wkt

from multiprocessing import Pool
import tqdm

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import base64
from IPython.display import HTML

import folium
import json
import concurrent.futures
import time
import logging

# %%
pd.set_option('display.max_columns', None) #Show all columns in pandas df
pd.set_option('display.max_rows', 100) #Show 100 rows in pandas df
pd.options.display.float_format = '{:.10f}'.format #Show float with 10 decimal points in pandas df

from IPython.core.interactiveshell import InteractiveShell #allow multiple outputs in one jupyter cell
InteractiveShell.ast_node_interactivity = "all"

# %%
pip install geodatasets
# Out:
# Closing down clientserver connection
# Collecting geodatasets
#   Downloading geodatasets-2023.12.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting pooch (from geodatasets)
#   Downloading pooch-1.8.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.8/site-packages (from pooch->geodatasets) (3.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from pooch->geodatasets) (23.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.8/site-packages (from pooch->geodatasets) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->pooch->geodatasets) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->pooch->geodatasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->pooch->geodatasets) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.19.0->pooch->geodatasets) (2022.12.7)
# Downloading geodatasets-2023.12.0-py3-none-any.whl (19 kB)
# Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 9.8 MB/s eta 0:00:00
# Installing collected packages: pooch, geodatasets
# Successfully installed geodatasets-2023.12.0 pooch-1.8.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
import geodatasets
import folium
import matplotlib.pyplot as plt
# Out:
# generated new fontManager

# %%
# !pip install dask
# !pip install dask[complete]
# Out:
# Closing down clientserver connection
# Collecting dask
#   Downloading dask-2023.5.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.6 MB/s eta 0:00:00
# Collecting partd>=1.2.0
#   Downloading partd-1.4.1-py3-none-any.whl (18 kB)
# Collecting cloudpickle>=1.5.0
#   Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: click>=8.0 in /opt/conda/lib/python3.8/site-packages (from dask) (8.1.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from dask) (23.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.8/site-packages (from dask) (6.0)
# Collecting toolz>=0.10.0
#   Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/conda/lib/python3.8/site-packages (from dask) (6.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/lib/python3.8/site-packages (from dask) (2022.11.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.8/site-packages (from importlib-metadata>=4.13.0->dask) (3.15.0)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: toolz, locket, cloudpickle, partd, dask
# Successfully installed cloudpickle-3.0.0 dask-2023.5.0 locket-1.0.0 partd-1.4.1 toolz-0.12.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Closing down clientserver connection
# Requirement already satisfied: dask[complete] in /opt/conda/lib/python3.8/site-packages (2023.5.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (6.0.0)
# Requirement already satisfied: click>=8.0 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (8.1.3)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (23.0)
# Requirement already satisfied: partd>=1.2.0 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (1.4.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (2022.11.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (6.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (3.0.0)
# Requirement already satisfied: pyarrow>=7.0 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (11.0.0)
# Collecting lz4>=4.3.2
#   Downloading lz4-4.3.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.8/site-packages (from importlib-metadata>=4.13.0->dask[complete]) (3.15.0)
# Requirement already satisfied: locket in /opt/conda/lib/python3.8/site-packages (from partd>=1.2.0->dask[complete]) (1.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /opt/conda/lib/python3.8/site-packages (from pyarrow>=7.0->dask[complete]) (1.23.5)
# Collecting distributed==2023.5.0
#   Downloading distributed-2023.5.0-py3-none-any.whl (966 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 966.6/966.6 kB 111.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (1.5.3)
# Requirement already satisfied: bokeh>=2.4.2 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (3.0.3)
# Requirement already satisfied: jinja2>=2.10.3 in /opt/conda/lib/python3.8/site-packages (from dask[complete]) (3.1.2)
# Collecting msgpack>=1.0.0
#   Downloading msgpack-1.0.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.5/390.5 kB 53.8 MB/s eta 0:00:00
# Collecting tblib>=1.6.0
#   Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Collecting zict>=2.2.0
#   Downloading zict-3.0.0-py2.py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=6.0.3 in /opt/conda/lib/python3.8/site-packages (from distributed==2023.5.0->dask[complete]) (6.2)
# Requirement already satisfied: urllib3>=1.24.3 in /opt/conda/lib/python3.8/site-packages (from distributed==2023.5.0->dask[complete]) (1.26.14)
# Collecting sortedcontainers>=2.0.5
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: psutil>=5.7.0 in /opt/conda/lib/python3.8/site-packages (from distributed==2023.5.0->dask[complete]) (5.9.4)
# Requirement already satisfied: pillow>=7.1.0 in /opt/conda/lib/python3.8/site-packages (from bokeh>=2.4.2->dask[complete]) (9.4.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /opt/conda/lib/python3.8/site-packages (from bokeh>=2.4.2->dask[complete]) (2023.2.0)
# Requirement already satisfied: contourpy>=1 in /opt/conda/lib/python3.8/site-packages (from bokeh>=2.4.2->dask[complete]) (1.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.8/site-packages (from jinja2>=2.10.3->dask[complete]) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.3->dask[complete]) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.3->dask[complete]) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=1.3->dask[complete]) (1.16.0)
# Installing collected packages: sortedcontainers, zict, tblib, msgpack, lz4, distributed
# Successfully installed distributed-2023.5.0 lz4-4.3.3 msgpack-1.0.8 sortedcontainers-2.4.0 tblib-3.0.0 zict-3.0.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import dask
import dask.dataframe as dd
from dask import delayed

# %%
#bucket = "ungp-ais-data-historical-backup"
#path = f"s3a://{bucket}/user_temp/adb/"
path = "s3a://ungp-ais-data-historical-backup/exact-earth-data/transformed/prod/"

# %% [markdown]
# # Import Data WPI

# %%
def get_wpi():
    # wpi = gpd.read_file("https://msi.nga.mil/api/publications/download?key=16694622/SFH00000/WPI_Shapefile.zip")
    
    wpi = pd.read_csv("https://raw.githubusercontent.com/muhammadhanief/cobapostgre/main/UpdatedPub150.csv") \
            [['World Port Index Number','Main Port Name','UN/LOCODE','Country Code','Harbor Size','Harbor Type','Latitude','Longitude']] \
            .rename(columns={'Country Code':'Country','Main Port Name':'Port'})
    
    geometry=gpd.points_from_xy(wpi['Longitude'],wpi['Latitude'])
    
    wpi = gpd.GeoDataFrame(wpi, geometry=geometry, crs="epsg:4326")
    return wpi

# %%
def get_utm():
    url = 'https://opendata.arcgis.com/datasets/b294795270aa4fb3bd25286bf09edc51_0.zip'
    utm = gpd.read_file(url)
    utm['UTM'] = utm['ZONE'].astype(str) + utm['ROW_']
    south = ['A','B','C','D','E','F','G','H','J','K','L','M']
    north = ['N','P','Q','R','S','T','U','V','W','X','Y','Z']
    utm['NS'] = np.where(utm['ROW_'].isin(north),"N","S")
    utm['prefix'] = np.where(utm['ROW_'].isin(north),"326","327")
    utm['EPSG'] = 'epsg:' + utm['prefix'] + utm['ZONE'].astype(str).str.zfill(2)
    return utm

# %%
def poly_to_h3(dfseries, h3_res=8):
    return dfseries.apply(lambda x: h3int.polyfill(mapping(x), h3_res, geo_json_conformant=True))

def h3_to_poly(df_series, crs='epsg:4326'):
    return gpd.GeoSeries(df_series.apply(lambda x: Polygon(h3int.h3_set_to_multi_polygon(x, geo_json=True)[0][0])), crs=crs)

def parallelize_dataframe(df, func,n_split=100, n_cores=4):
    df_split = np.array_split(df, n_split)
    pool = Pool(n_cores) 
    mapped_values = list(tqdm.tqdm(pool.imap_unordered(func, df_split), total=n_split))
    pool.close()
    pool.join()
    return pd.concat(mapped_values).sort_index()

# %%
# def poly_to_h3(dfseries, h3_res=8):
#     return dfseries.apply(lambda x: h3.polyfill(mapping(x), h3_res, geo_json_conformant=True))

# def poly_to_h3_12(dfseries, h3_res=12):
#     return dfseries.apply(lambda x: h3.polyfill(mapping(x), h3_res, geo_json_conformant=True))

# def h3_to_poly(df_series, crs='epsg:4326'):
#     return gpd.GeoSeries(df_series.apply(lambda x: Polygon(h3.h3_set_to_multi_polygon(x, geo_json=True)[0][0])), crs=crs)

# def parallelize_dataframe(df, func, n_split=100, n_cores=4):
#     df_split = np.array_split(df, n_split)
#     pool = Pool(n_cores)
#     mapped_values = list(tqdm.tqdm(pool.imap_unordered(func, df_split), total=n_split))
#     pool.close()
#     pool.join()
#     return pd.concat(mapped_values).sort_index()

# def poly_to_h3_wrapper(df, h3_res=8):
#     return df.apply(lambda polygon: poly_to_h3(pd.Series([polygon]), h3_res=h3_res).iloc[0] if polygon.is_valid and polygon.geom_type == 'Polygon' else [])

# def poly_to_h3_12_wrapper(df, h3_res=12):
#     return df.apply(lambda polygon: poly_to_h3_12(pd.Series([polygon]), h3_res=h3_res).iloc[0] if polygon.is_valid and polygon.geom_type == 'Polygon' else [])

# def h3_to_poly_wrapper(df, crs='epsg:4326'):
#     return df.apply(lambda h3_indices: h3_to_poly(pd.Series([h3_indices]), crs=crs).iloc[0] if h3_indices else gpd.GeoSeries([None], crs=crs).iloc[0])

# def poly_to_h3_wrapper_func(df):
#     return poly_to_h3_wrapper(df, h3_res=8)

# def h3_to_poly_wrapper_func(df):
#     return h3_to_poly_wrapper(df, crs='epsg:4326')

# %% [markdown]
# # Port

# %% [markdown]
# ## Call Func

# %%
wpi = get_wpi()
utm = get_utm()

# %%
wpi.info()
utm.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3824 entries, 0 to 3823
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   World Port Index Number  3824 non-null   float64
#  1   Port                     3824 non-null   object
#  2   UN/LOCODE                3824 non-null   object
#  3   Country                  3824 non-null   object
#  4   Harbor Size              3824 non-null   object
#  5   Harbor Type              3824 non-null   object
#  6   Latitude                 3824 non-null   float64
#  7   Longitude                3824 non-null   float64
#  8   geometry                 3824 non-null   geometry
# dtypes: float64(3), geometry(1), object(5)
# memory usage: 269.0+ KB
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1201 entries, 0 to 1200
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID         1201 non-null   int64
#  1   ZONE        1201 non-null   int64
#  2   ROW_        1201 non-null   object
#  3   WEST_VALUE  1201 non-null   object
#  4   CM_VALUE    1201 non-null   object
#  5   EAST_VALUE  1201 non-null   object
#  6   geometry    1201 non-null   geometry
#  7   UTM         1201 non-null   object
#  8   NS          1201 non-null   object
#  9   prefix      1201 non-null   object
#  10  EPSG        1201 non-null   object
# dtypes: geometry(1), int64(2), object(8)
# memory usage: 103.3+ KB

# %%
#There are duplicated WPIs, keep first
wpi[wpi.duplicated(subset=['World Port Index Number'], keep=False)]
# Out:
#       World Port Index Number             Port UN/LOCODE  Country Harbor Size  \
# 92           49460.0000000000    Machilipatnam              India  Very Small
# 2027           400.0000000000  Seydhisfjordhur    IS SEY  Iceland       Small
# 3118         49460.0000000000    Machilipatnam              India  Very Small
# 3548           400.0000000000    Seydisfjordur     ISSEY  Iceland
#
#             Harbor Type      Latitude      Longitude  \
# 92       Open Roadstead 16.1500000000  81.1666670000
# 2027  Coastal (Natural) 65.2666670000 -14.0000000000
# 3118     Open Roadstead 16.1500000000  81.1500000000
# 3548                    65.2666666700 -14.0000000000
#
#                         geometry
# 92     POINT (81.16667 16.15000)
# 2027  POINT (-14.00000 65.26667)
# 3118   POINT (81.15000 16.15000)
# 3548  POINT (-14.00000 65.26667)

# %%
wpi.drop_duplicates(subset=['World Port Index Number'], keep='first', inplace=True)

# %% [markdown]
# ## Special Cases:

# %%
#Drop duplicates based on H3 resolution 8
wpi['h3'] = wpi[['Latitude','Longitude']].apply(lambda x: h3int.geo_to_h3(x[0],x[1],8), axis=1)
wpi[wpi.duplicated(subset=['h3'], keep=False)].sort_values(['h3'])
# Out:
#       World Port Index Number                Port UN/LOCODE         Country  \
# 2933         28490.0000000000         Paljassaare    EE PAS         Estonia
# 2085         28492.0000000000             Lahesuu    EE LHS         Estonia
# 1890         19785.0000000000          Coal Point             United States
# 1484         19781.0000000000               Homer    US HOM   United States
# 225          19588.0000000000              Haines    US HNS   United States
# 184          19585.0000000000       Port Chilkoot             United States
# 249          31375.0000000000       Isle Of Grain    GB IOG  United Kingdom
# 2668         31376.0000000000          Thamesport    GB THP  United Kingdom
# 478          16805.0000000000             Glenada             United States
# 480          16803.0000000000            Florence    US FNE   United States
# 2414          7940.0000000000             Sewaren    US SWN   United States
# 139           7890.0000000000         Port Socony             United States
# 2484          7870.0000000000         Gulfport SI             United States
# 2278          7895.0000000000              Bayway    US 8BY   United States
# 3016          7840.0000000000    Tompkinsville SI             United States
# 3021          7830.0000000000        Stapleton SI             United States
# 449           8110.0000000000        Philadelphia    US PHL   United States
# 1047          8130.0000000000              Camden    US CDE   United States
# 3425          9930.0000000000            Freeport     BMFPT         Bermuda
# 525           9950.0000000000      Ireland Island    BM FPT         Bermuda
# 1921          3650.0000000000      Walpole Island                    Canada
# 1528          4320.0000000000             Algonac    US ALG   United States
# 568           2520.0000000000              Ottawa    CA OTT          Canada
# 2049          2530.0000000000                Hull    CA HUL          Canada
# 2420          7730.0000000000          Rensselaer    US RER   United States
# 1055          7720.0000000000              Albany    US ALB   United States
# 1869         61573.0000000000            Kakogawa    JP KGA           Japan
# 1868         61568.0000000000      Higashi-Harima    JP HHR           Japan
# 2475         50922.0000000000  Merak Mas Terminal    ID MRK       Indonesia
# 831          50935.0000000000      Tanjung Sekong    ID TSE       Indonesia
#
#      Harbor Size           Harbor Type      Latitude       Longitude  \
# 2933      Medium  Coastal (Breakwater) 59.4591020000   24.7056400000
# 2085  Very Small  Coastal (Breakwater) 59.4570562000   24.7030027200
# 1890  Very Small     Coastal (Natural) 59.6014000000 -151.4111000000
# 1484  Very Small     Coastal (Natural) 59.6000000000 -151.4166670000
# 225   Very Small     Coastal (Natural) 59.2333330000 -135.4333330000
# 184   Very Small     Coastal (Natural) 59.2333330000 -135.4333330000
# 249        Small     Coastal (Natural) 51.4333330000    0.7000000000
# 2668       Small       River (Natural) 51.4333330000    0.7000000000
# 478   Very Small       River (Natural) 43.9666670000 -124.1166670000
# 480   Very Small       River (Natural) 43.9666670000 -124.1166670000
# 2414  Very Small       River (Natural) 40.5500000000  -74.2500000000
# 139        Small       River (Natural) 40.5500000000  -74.2500000000
# 2484       Small       River (Natural) 40.6333330000  -74.2000000000
# 2278  Very Small       River (Natural) 40.6333330000  -74.2000000000
# 3016      Medium     Coastal (Natural) 40.6333330000  -74.0666670000
# 3021       Small     Coastal (Natural) 40.6333330000  -74.0666670000
# 449        Large       River (Natural) 39.9500000000  -75.1333330000
# 1047      Medium       River (Natural) 39.9500000000  -75.1333330000
# 3425                                   32.3166666700  -64.8333333300
# 525       Medium  Coastal (Breakwater) 32.3166670000  -64.8333330000
# 1921  Very Small       River (Natural) 42.6166670000  -82.5166670000
# 1528  Very Small       River (Natural) 42.6166670000  -82.5166670000
# 568        Small       River (Natural) 45.4333330000  -75.7000000000
# 2049  Very Small       River (Natural) 45.4333330000  -75.7000000000
# 2420  Very Small       River (Natural) 42.6500000000  -73.7500000000
# 1055      Medium       River (Natural) 42.6500000000  -73.7500000000
# 1869  Very Small  Coastal (Breakwater) 34.7000000000  134.8333330000
# 1868      Medium  Coastal (Breakwater) 34.7000000000  134.8333330000
# 2475      Medium     Coastal (Natural) -5.9191666670  105.9972222000
# 831   Very Small     Coastal (Natural) -5.9166670000  106.0000000000
#
#                          geometry                  h3
# 2933    POINT (24.70564 59.45910)  612640945388650495
# 2085    POINT (24.70300 59.45706)  612640945388650495
# 1890  POINT (-151.41110 59.60140)  612706276754849791
# 1484  POINT (-151.41667 59.60000)  612706276754849791
# 225   POINT (-135.43333 59.23333)  612833771728666623
# 184   POINT (-135.43333 59.23333)  612833771728666623
# 249      POINT (0.70000 51.43333)  612934725060788223
# 2668     POINT (0.70000 51.43333)  612934725060788223
# 478   POINT (-124.11667 43.96667)  613195105995587583
# 480   POINT (-124.11667 43.96667)  613195105995587583
# 2414   POINT (-74.25000 40.55000)  613229546822434815
# 139    POINT (-74.25000 40.55000)  613229546822434815
# 2484   POINT (-74.20000 40.63333)  613229547254448127
# 2278   POINT (-74.20000 40.63333)  613229547254448127
# 3016   POINT (-74.06667 40.63333)  613229552165978111
# 3021   POINT (-74.06667 40.63333)  613229552165978111
# 449    POINT (-75.13333 39.95000)  613229748069335039
# 1047   POINT (-75.13333 39.95000)  613229748069335039
# 3425   POINT (-64.83333 32.31667)  613233649527029759
# 525    POINT (-64.83333 32.31667)  613233649527029759
# 1921   POINT (-82.51667 42.61667)  613240692677804031
# 1528   POINT (-82.51667 42.61667)  613240692677804031
# 568    POINT (-75.70000 45.43333)  613255063067951103
# 2049   POINT (-75.70000 45.43333)  613255063067951103
# 2420   POINT (-73.75000 42.65000)  613255428582670335
# 1055   POINT (-73.75000 42.65000)  613255428582670335
# 1869   POINT (134.83333 34.70000)  613306229596356607
# 1868   POINT (134.83333 34.70000)  613306229596356607
# 2475   POINT (105.99722 -5.91917)  614953762219360255
# 831    POINT (106.00000 -5.91667)  614953762219360255

# %%
wpi.head(3)
# Out:
#    World Port Index Number                   Port UN/LOCODE        Country  \
# 0          7950.0000000000                 Maurer            United States
# 1         52235.0000000000  Mangkasa Oil Terminal                Indonesia
# 2         47620.0000000000                Iharana               Madagascar
#
#   Harbor Size        Harbor Type       Latitude      Longitude  \
# 0  Very Small    River (Natural)  40.5333330000 -74.2500000000
# 1       Small     Open Roadstead  -2.7333330000 121.0666670000
# 2  Very Small  Coastal (Natural) -13.3500000000  50.0000000000
#
#                      geometry                  h3
# 0  POINT (-74.25000 40.53333)  613229546881155071
# 1  POINT (121.06667 -2.73333)  615113573061885951
# 2  POINT (50.00000 -13.35000)  615364915363839999

# %%
# fungsi generate h3 from lat and long
def get_k_ring_indices(lat, lng, k):
    k_ring = un.k_ring(un.get_h3_index(lat,lng,8),k=k)
    the_h3_list = []
    for element in k_ring:
        H3_int = h3.string_to_h3(element)
        the_h3_list.append(H3_int)
    return the_h3_list
    # return un.k_ring(un.get_h3_index(lat,lng,4),k=k)

# %%
# Tambahkan kolom 'k_ring' ke DataFrame
wpi['h3_k_ring'] = wpi.apply(lambda row: get_k_ring_indices(row['Latitude'], row['Longitude'], 22), axis=1)

# %%
# Hasil penambahan kolom k_ring
wpi.head(3)
# Out:
#    World Port Index Number                   Port UN/LOCODE        Country  \
# 0          7950.0000000000                 Maurer            United States
# 1         52235.0000000000  Mangkasa Oil Terminal                Indonesia
# 2         47620.0000000000                Iharana               Madagascar
#
#   Harbor Size        Harbor Type       Latitude      Longitude  \
# 0  Very Small    River (Natural)  40.5333330000 -74.2500000000
# 1       Small     Open Roadstead  -2.7333330000 121.0666670000
# 2  Very Small  Coastal (Natural) -13.3500000000  50.0000000000
#
#                      geometry                  h3  \
# 0  POINT (-74.25000 40.53333)  613229546881155071
# 1  POINT (121.06667 -2.73333)  615113573061885951
# 2  POINT (50.00000 -13.35000)  615364915363839999
#
#                                            h3_k_ring
# 0  [613229768426389503, 613229546918903807, 61322...
# 1  [615113569091977215, 615113572587929599, 61511...
# 2  [615364914709528575, 615364911626715135, 61536...

# %%
wpi.drop_duplicates(subset=['h3'], ignore_index=True, inplace=True)

# %%
wpi.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3807 entries, 0 to 3806
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   World Port Index Number  3807 non-null   float64
#  1   Port                     3807 non-null   object
#  2   UN/LOCODE                3807 non-null   object
#  3   Country                  3807 non-null   object
#  4   Harbor Size              3807 non-null   object
#  5   Harbor Type              3807 non-null   object
#  6   Latitude                 3807 non-null   float64
#  7   Longitude                3807 non-null   float64
#  8   geometry                 3807 non-null   geometry
#  9   h3                       3807 non-null   int64
#  10  h3_k_ring                3807 non-null   object
# dtypes: float64(3), geometry(1), int64(1), object(6)
# memory usage: 327.3+ KB

# %% [markdown]
# ## Save

# %%
save_path = "s3a://ungp-ais-data-historical-backup/user_temp/"
save_path_unique = save_path + "222011349/"

# %%
wpi.to_pickle(save_path_unique+"WPI.pkl")
utm.to_pickle(save_path_unique+"UTM.pkl")

# %% [markdown]
# # AOI

# %%
# def extract_boundary_and_h3(df, buffer_label):
#     # Ekstrak batas poligon buffer
#     df['boundary'] = df[buffer_label].boundary

#     # Ubah LineString menjadi Polygon jika valid
#     df['boundary_polygon'] = df['boundary'].apply(lambda line: Polygon(line) if line.is_valid else None)

#     # Konversi batas ke H3 indices (res 8)
#     df['boundary_h3_8'] = df['boundary_polygon'].apply(lambda poly: poly_to_h3_wrapper(pd.Series([poly]), h3_res=8).iloc[0] if poly else [])

#     # Konversi batas ke H3 indices (res 12)
#     df['boundary_h3_12'] = df['boundary_polygon'].apply(lambda poly: poly_to_h3_12_wrapper(pd.Series([poly]), h3_res=12).iloc[0] if poly else [])

#     return df

# %%
# # Configure logging
# logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# def wpi_buffer_combined(wpi, utm, buffer_dist_km=22, return_grouped=True):
#     buffer_label = f"buffer_{buffer_dist_km}KM"

#     logging.info(f"WPI Rows: {wpi.shape[0]:,}")

#     try:
#         # Gabungkan poligon UTM per EPSG
#         utm_agg = utm[~utm['ZONE'].isin(['A','B','Y','Z'])][['EPSG', 'geometry']].dissolve(by=['EPSG'], as_index=False)

#         # Lampirkan informasi UTM ke WPI jika poligon WPI berada dalam poligon UTM yang digabungkan
#         df = gpd.sjoin(wpi[['Country', 'Port', 'World Port Index Number', 'geometry', 'h3_k_ring']].rename(columns={'World Port Index Number': 'port_id'}),
#                        utm_agg, predicate='within').drop(columns=['index_right'])
#         logging.info(f"WPI with points within UTM Zone: {df.shape[0]:,}")

#         # Generate buffer untuk setiap batch EPSG
#         base_crs = df.crs
#         for epsg in df['EPSG'].unique():
#             cond = df['EPSG'] == epsg
#             df_small = df[cond].copy()
#             df_small.to_crs(epsg, inplace=True)
#             df_small[buffer_label] = df_small.buffer(buffer_dist_km * 1000, cap_style=3)
#             df_small.set_geometry(buffer_label, inplace=True)
#             df_small["buffer_area"] = df_small.area
#             df_small.to_crs(base_crs, inplace=True)
#             df.loc[cond, [buffer_label, "buffer_area"]] = df_small[[buffer_label, "buffer_area"]]
#         logging.info("Buffer generation complete")

#         # Set geometrinya ke buffer
#         df = df.set_geometry(buffer_label).rename(columns={"geometry": "location"})

#         # Gabungkan buffer yang tumpang tindih untuk membuat buffer yang dikelompokkan
#         df2 = df[[buffer_label]].dissolve().explode(index_parts=True).reset_index(drop=True)
#         df2['buffer_grouped_id'] = np.arange(df2.shape[0])
#         df2[buffer_label + "_grouped"] = df2[buffer_label]

#         # Set CRS untuk buffer_grouped ke EPSG:4326
#         df2.set_crs(epsg="4326", inplace=True)
#         logging.info("Dissolve and explode complete")

#         logging.info("Starting H3 index generation")
#         start_time = time.time()
#         df2['buffer_grouped_h3'] = parallelize_dataframe(df2[buffer_label], poly_to_h3_wrapper_func)
#         logging.info(f"Time after generating H3 indices: {time.time() - start_time:.2f} seconds")

#         logging.info("Starting H3 to polygon conversion")
#         start_time = time.time()
#         df2['buffer_h3_poly'] = parallelize_dataframe(df2['buffer_grouped_h3'], h3_to_poly_wrapper_func)
#         logging.info(f"Time after converting H3 indices to polygons: {time.time() - start_time:.2f} seconds")

#         df4 = df2[['buffer_grouped_h3', 'buffer_grouped_id']].explode('buffer_grouped_h3', ignore_index=True)

#         # Sisipkan informasi buffer yang dikelompokkan
#         logging.info("Starting spatial join")
#         start_time = time.time()
#         df3 = gpd.sjoin(df.set_geometry("location"),
#                         df2.drop(columns=['buffer_grouped_h3']),
#                         how='left',
#                         predicate='within').drop(columns=['index_right'])
#         logging.info(f"Time after spatial join: {time.time() - start_time:.2f} seconds")

#         df3['grouped_country'] = df3['buffer_grouped_id'].map(df3.groupby('buffer_grouped_id')['Country'].agg(set))
#         df3['grouped_port'] = df3['buffer_grouped_id'].map(df3.groupby('buffer_grouped_id')["Port"].agg(set))

#         df3.set_geometry(buffer_label + "_grouped", inplace=True)
#         df3.set_crs(epsg="4326", inplace=True)

#         logging.info("Starting boundary extraction and H3 conversion")
#         start_time = time.time()
#         df3 = extract_boundary_and_h3(df3, buffer_label)
#         logging.info(f"Time after extracting boundaries and converting to H3: {time.time() - start_time:.2f} seconds")

#         logging.info("Selesai")
#         return df3, df4
#     except Exception as e:
#         logging.error(f"Error during execution: {e}", exc_info=True)
#         raise

# %%
# # Jalankan fungsi
# ports_df, ports_grouped_df = wpi_buffer_combined(wpi, utm, buffer_dist_km=22)
# Out:
# WPI Rows: 3,807
# WPI with points within UTM Zone: 3,807
# Buffer generation complete
# Dissolve and explode complete
# Starting H3 index generation
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# 100%|██████████| 100/100 [00:08<00:00, 11.38it/s]
# Closing down clientserver connection
# Closing down clientserver connection
# Time after generating H3 indices: 8.94 seconds
# Starting H3 to polygon conversion
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# 100%|██████████| 100/100 [00:19<00:00,  5.23it/s]
# Starting H3 to polygon conversion
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# Time after converting H3 indices to polygons: 19.31 seconds
# Starting spatial join
# Time after spatial join: 0.03 seconds
# Starting boundary extraction and H3 conversion

# %%
def extract_boundary_and_h3(df, buffer_label):
    # Ekstrak batas poligon buffer_22KM
    df['boundary'] = df[buffer_label].boundary

    # Ubah LineString menjadi Polygon
    df['boundary_polygon'] = df['boundary'].apply(lambda line: Polygon(line))

    # Konversi batas ke H3 indices
    df['boundary_h3_8'] = poly_to_h3(df['boundary_polygon'], h3_res=8)

    return df

# %%
def wpi_buffer_combined(wpi, utm, buffer_dist_km=22, return_grouped=True):
    buffer_label = f"buffer_{buffer_dist_km}KM"

    print(f"WPI Rows: {wpi.shape[0]:,}")
    
    #aggregate UTM polygons per EPSG
    utm_agg = utm[~utm['ZONE'].isin(['A','B','Y','Z'])][['EPSG','geometry']].dissolve(by=['EPSG'],as_index=False)
    
    #attach UTM info to wpi if wpi polygon is in utm aggregated polygon
    df = gpd.sjoin(wpi[['Country','Port','World Port Index Number','geometry','h3_k_ring']].rename(columns={'World Port Index Number':'port_id'}),
                   utm_agg, predicate='within').drop(columns=['index_right'])
    print(f"WPI with points within UTM Zone: {df.shape[0]:,}")
    
    #generate buffer for each epsg batch
    base_crs = df.crs
    for epsg in df['EPSG'].unique():
        cond = df['EPSG'] == epsg
        df_small = df[cond].copy()
        df_small.to_crs(epsg, inplace=True)
        df_small[buffer_label] = df_small.buffer(buffer_dist_km*1000, cap_style=3)
        df_small.set_geometry(buffer_label, inplace=True)
        df_small["buffer_area"] = df_small.area
        df_small.to_crs(base_crs, inplace=True)

        df.loc[cond,[buffer_label, "buffer_area"]] = df_small[[buffer_label, "buffer_area"]]

    
    # Sisipkan informasi UTM buffer, ini akan memotong buffer menjadi setiap UTM
    df = df.set_geometry(buffer_label).rename(columns={"geometry": "location"})

    # Gabungkan buffer yang tumpang tindih untuk membuat buffer yang dikelompokkan
    df2 = df[[buffer_label]].dissolve().explode(index_parts=True).reset_index(drop=True)
    df2['buffer_grouped_id'] = np.arange(df2.shape[0])
    df2[buffer_label + "_grouped"] = df2[buffer_label]

    print("Menghasilkan indeks H3 untuk buffer yang dikelompokkan..")

    df2['buffer_grouped_h3'] = parallelize_dataframe(df2[buffer_label], poly_to_h3, 100, 4)

    print("Mengkonversi indeks H3 menjadi poligon..")
    df2['buffer_h3_poly'] = parallelize_dataframe(df2['buffer_grouped_h3'], h3_to_poly, 100, 4)

    df4 = df2[['buffer_grouped_h3', 'buffer_grouped_id']].explode('buffer_grouped_h3', ignore_index=True)

    # Sisipkan informasi buffer yang dikelompokkan
    df3 = gpd.sjoin(df.set_geometry("location"),
                    df2.drop(columns=['buffer_grouped_h3']),
                    how='left',
                    predicate='within').drop(columns=['index_right'])
    df3['grouped_country'] = df3['buffer_grouped_id'].map(df3.groupby('buffer_grouped_id')['Country'].agg(set))
    df3['grouped_port'] = df3['buffer_grouped_id'].map(df3.groupby('buffer_grouped_id')["Port"].agg(set))

    df3.set_geometry(buffer_label + "_grouped", inplace=True)
    df3.set_crs(epsg="4326", inplace=True)

    # Ekstrak batas dan konversi ke H3 indices
    df3 = extract_boundary_and_h3(df3, buffer_label)
    
    print("Selesai")
    return df3, df4

# %% [markdown]
# ## Generate buffers

# %%
#note, we parallellize conversion of polygons to h3 indices because it takes a while to convert in series, at least 5 mins for 1000K rows
ports_df, ports_grouped_df = wpi_buffer_combined(wpi, utm, buffer_dist_km=22)
# Out:
# WPI Rows: 3,807
# WPI with points within UTM Zone: 3,807
# Menghasilkan indeks H3 untuk buffer yang dikelompokkan..
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# 100%|██████████| 100/100 [00:06<00:00, 16.39it/s]
# Closing down clientserver connection
# Closing down clientserver connection
# Mengkonversi indeks H3 menjadi poligon..
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# 100%|██████████| 100/100 [00:12<00:00,  7.94it/s]
# Closing down clientserver connection
# Closing down clientserver connection
# /tmp/ipykernel_51/16693839.py:46: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: None
#
#   df3 = gpd.sjoin(df.set_geometry("location"),
# Selesai

# %%
ports_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 3807 entries, 0 to 3718
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              3807 non-null   object
#  1   Port                 3807 non-null   object
#  2   port_id              3807 non-null   float64
#  3   location             3807 non-null   geometry
#  4   h3_k_ring            3807 non-null   object
#  5   EPSG                 3807 non-null   object
#  6   buffer_22KM          3807 non-null   geometry
#  7   buffer_area          3807 non-null   float64
#  8   buffer_grouped_id    3807 non-null   int64
#  9   buffer_22KM_grouped  3807 non-null   geometry
#  10  buffer_h3_poly       3807 non-null   geometry
#  11  grouped_country      3807 non-null   object
#  12  grouped_port         3807 non-null   object
#  13  boundary             3807 non-null   geometry
#  14  boundary_polygon     3807 non-null   geometry
#  15  boundary_h3_8        3807 non-null   object
# dtypes: float64(2), geometry(6), int64(1), object(7)
# memory usage: 505.6+ KB

# %% [markdown]
# ## Port Indonesia

# %%
ports_df[ports_df['Country']=="Indonesia"]
# Out:
#         Country                   Port          port_id  \
# 1     Indonesia  Mangkasa Oil Terminal 52235.0000000000
# 323   Indonesia                Kendari 52240.0000000000
# 452   Indonesia                Pomalaa 52295.0000000000
# 583   Indonesia                 Kupang 51400.0000000000
# 1626  Indonesia                Maumere 51320.0000000000
# ...         ...                    ...              ...
# 439   Indonesia            Teluk Bayur 50450.0000000000
# 852   Indonesia                Merauke 53130.0000000000
# 1800  Indonesia               Jayapura 53133.0000000000
# 2852  Indonesia              Uleelheue 50600.0000000000
# 2894  Indonesia                 Sabang 50610.0000000000
#
#                          location  \
# 1      POINT (121.06667 -2.73333)
# 323    POINT (122.58333 -3.96667)
# 452    POINT (121.60000 -4.16667)
# 583   POINT (123.58333 -10.16667)
# 1626   POINT (122.21667 -8.61667)
# ...                           ...
# 439    POINT (100.36667 -1.00000)
# 852    POINT (140.38333 -8.48333)
# 1800   POINT (140.71667 -2.53333)
# 2852     POINT (95.28333 5.56667)
# 2894     POINT (95.31667 5.88333)
#
#                                               h3_k_ring        EPSG  \
# 1     [615113569091977215, 615113572587929599, 61511...  epsg:32751
# 323   [615118949972967423, 615118951984136191, 61511...  epsg:32751
# 452   [615113795617947647, 615113793992654847, 61511...  epsg:32751
# 583   [615093508310564863, 615093502180589567, 61509...  epsg:32751
# 1626  [615095841031454719, 615095842321203199, 61509...  epsg:32751
# ...                                                 ...         ...
# 439   [614966846522654719, 614966846197596159, 61496...  epsg:32747
# 852   [615247305584410623, 615247305710239743, 61524...  epsg:32754
# 1800  [614511780697210879, 614511776488226815, 61451...  epsg:32754
# 2852  [614272118818865151, 614272119166992383, 61427...  epsg:32646
# 2894  [614251831320641535, 614251827629654015, 61425...  epsg:32646
#
#                                             buffer_22KM           buffer_area  \
# 1     POLYGON ((121.26477 -2.53469, 121.26420 -2.932... 1936000000.0000000000
# 323   POLYGON ((122.78156 -3.76771, 122.78146 -4.165... 1936000000.0000000000
# 452   POLYGON ((121.79847 -3.96801, 121.79787 -4.365... 1936000000.0000000000
# 583   POLYGON ((123.78368 -9.96729, 123.78465 -10.36... 1936000000.0000000000
# 1626  POLYGON ((122.41690 -8.41804, 122.41629 -8.816... 1936000000.0000000000
# ...                                                 ...                   ...
# 439   POLYGON ((100.56426 -0.80095, 100.56444 -1.198... 1936000000.0000000000
# 852   POLYGON ((140.58342 -8.28460, 140.58299 -8.682... 1936000000.0000000000
# 1800  POLYGON ((140.91458 -2.33432, 140.91455 -2.732... 1936000000.0000000000
# 2852  POLYGON ((95.48265 5.76470, 95.48098 5.36703, ... 1936000000.0000000000
# 2894  POLYGON ((95.51615 6.08130, 95.51436 5.68365, ... 1936000000.0000000000
#
#       buffer_grouped_id                                buffer_22KM_grouped  \
# 1                  1197  POLYGON ((121.26477 -2.53469, 121.26420 -2.932...
# 323                1195  POLYGON ((122.78156 -3.76771, 122.78146 -4.165...
# 452                1193  POLYGON ((121.79847 -3.96801, 121.79787 -4.365...
# 583                1182  POLYGON ((123.78368 -9.96729, 123.78465 -10.36...
# 1626               1186  POLYGON ((122.41690 -8.41804, 122.41629 -8.816...
# ...                 ...                                                ...
# 439                1083  POLYGON ((100.56426 -0.80095, 100.56444 -1.198...
# 852                1440  POLYGON ((140.58342 -8.28460, 140.58299 -8.682...
# 1800               1453  POLYGON ((140.91458 -2.33432, 140.91455 -2.732...
# 2852               1112  POLYGON ((95.11763 5.76616, 95.11883 6.08300, ...
# 2894               1112  POLYGON ((95.11763 5.76616, 95.11883 6.08300, ...
#
#                                          buffer_h3_poly grouped_country  \
# 1     POLYGON ((121.26260 -2.66655, 121.26330 -2.661...     {Indonesia}
# 323   POLYGON ((122.64982 -4.16353, 122.65433 -4.161...     {Indonesia}
# 452   POLYGON ((121.67097 -4.36783, 121.67544 -4.366...     {Indonesia}
# 583   POLYGON ((123.76027 -10.36381, 123.76480 -10.3...     {Indonesia}
# 1626  POLYGON ((122.35769 -8.81768, 122.36216 -8.816...     {Indonesia}
# ...                                                 ...             ...
# 439   POLYGON ((100.36122 -0.80571, 100.35701 -0.802...     {Indonesia}
# 852   POLYGON ((140.27577 -8.68071, 140.28064 -8.678...     {Indonesia}
# 1800  POLYGON ((140.51561 -2.46092, 140.51961 -2.464...     {Indonesia}
# 2852  POLYGON ((95.12016 5.95336, 95.11978 5.94813, ...     {Indonesia}
# 2894  POLYGON ((95.12016 5.95336, 95.11978 5.94813, ...     {Indonesia}
#
#                  grouped_port  \
# 1     {Mangkasa Oil Terminal}
# 323                 {Kendari}
# 452                 {Pomalaa}
# 583                  {Kupang}
# 1626                {Maumere}
# ...                       ...
# 439             {Teluk Bayur}
# 852                 {Merauke}
# 1800               {Jayapura}
# 2852      {Sabang, Uleelheue}
# 2894      {Sabang, Uleelheue}
#
#                                                boundary  \
# 1     LINESTRING (121.26477 -2.53469, 121.26420 -2.9...
# 323   LINESTRING (122.78156 -3.76771, 122.78146 -4.1...
# 452   LINESTRING (121.79847 -3.96801, 121.79787 -4.3...
# 583   LINESTRING (123.78368 -9.96729, 123.78465 -10....
# 1626  LINESTRING (122.41690 -8.41804, 122.41629 -8.8...
# ...                                                 ...
# 439   LINESTRING (100.56426 -0.80095, 100.56444 -1.1...
# 852   LINESTRING (140.58342 -8.28460, 140.58299 -8.6...
# 1800  LINESTRING (140.91458 -2.33432, 140.91455 -2.7...
# 2852  LINESTRING (95.48265 5.76470, 95.48098 5.36703...
# 2894  LINESTRING (95.51615 6.08130, 95.51436 5.68365...
#
#                                        boundary_polygon  \
# 1     POLYGON ((121.26477 -2.53469, 121.26420 -2.932...
# 323   POLYGON ((122.78156 -3.76771, 122.78146 -4.165...
# 452   POLYGON ((121.79847 -3.96801, 121.79787 -4.365...
# 583   POLYGON ((123.78368 -9.96729, 123.78465 -10.36...
# 1626  POLYGON ((122.41690 -8.41804, 122.41629 -8.816...
# ...                                                 ...
# 439   POLYGON ((100.56426 -0.80095, 100.56444 -1.198...
# 852   POLYGON ((140.58342 -8.28460, 140.58299 -8.682...
# 1800  POLYGON ((140.91458 -2.33432, 140.91455 -2.732...
# 2852  POLYGON ((95.48265 5.76470, 95.48098 5.36703, ...
# 2894  POLYGON ((95.51615 6.08130, 95.51436 5.68365, ...
#
#                                           boundary_h3_8
# 1     {8895288363fffff, 889528944bfffff, 88952c2b45f...
# 323   {889576d41dfffff, 889576c9abfffff, 88952ba6b9f...
# 452   {88952bc935fffff, 88952b52e3fffff, 88952bd1cbf...
# 583   {8894048e53fffff, 8894049727fffff, 8894048051f...
# 1626  {8894268937fffff, 8894268451fffff, 8894268da7f...
# ...                                                 ...
# 439   {888cd3b049fffff, 888cd16b39fffff, 888cd16a03f...
# 852   {889cc2a2a5fffff, 889cc2a31dfffff, 889cc2a305f...
# 1800  {8872f356ebfffff, 8872f3473dfffff, 8872f37257f...
# 2852  {886553ccd9fffff, 886553ce25fffff, 886553cee3f...
# 2894  {88655341b5fffff, 88642c9407fffff, 88642c8647f...
#
# [122 rows x 16 columns]

# %%
ports_indo_df = ports_df[ports_df['Country']=="Indonesia"]

# %%
len(ports_indo_df)
# Out:
# 122

# %%
ports_indo_df_x = ports_df[ports_df['Port']=="Tanah Merah"]

# %%
ports_indo_df_y = ports_df[ports_df['Port']=="Merak Mas Terminal"]

# %%
ports_indo_df_y
# Out:
# Empty GeoDataFrame
# Columns: [Country, Port, port_id, location, h3_k_ring, EPSG, buffer_22KM, buffer_area, buffer_grouped_id, buffer_22KM_grouped, buffer_h3_poly, grouped_country, grouped_port, boundary, boundary_polygon, boundary_h3_8]
# Index: []

# %%
ports_indo_df_z = ports_df[ports_df['Port']=="Tanjung Sekong"]

# %%
ports_indo_df_z
# Out:
#        Country            Port          port_id                    location  \
# 829  Indonesia  Tanjung Sekong 50935.0000000000  POINT (106.00000 -5.91667)
#
#                                              h3_k_ring        EPSG  \
# 829  [614953766640156671, 614953762217263103, 61495...  epsg:32748
#
#                                            buffer_22KM           buffer_area  \
# 829  POLYGON ((106.19830 -5.71730, 106.19916 -6.115... 1936000000.0000000000
#
#      buffer_grouped_id                                buffer_22KM_grouped  \
# 829               1067  POLYGON ((105.80105 -5.76796, 105.80098 -5.717...
#
#                                         buffer_h3_poly grouped_country  \
# 829  POLYGON ((105.89679 -6.25095, 105.90131 -6.248...     {Indonesia}
#
#                                           grouped_port  \
# 829  {Tanjung Sekong, Anyer Lor, Banten, Tanjung Ge...
#
#                                               boundary  \
# 829  LINESTRING (106.19830 -5.71730, 106.19916 -6.1...
#
#                                       boundary_polygon  \
# 829  POLYGON ((106.19830 -5.71730, 106.19916 -6.115...
#
#                                          boundary_h3_8
# 829  {888c13013dfffff, 888c1314ddfffff, 888c1338c1f...

# %%
ports_indo_df_w = ports_df[ports_df['Port']=="Amamapare"]

# %%
ports_indo_df_w
# Out:
#        Country       Port          port_id                    location  \
# 350  Indonesia  Amamapare 53115.0000000000  POINT (136.96667 -4.81667)
#
#                                              h3_k_ring        EPSG  \
# 350  [614504599876796415, 614505894102695935, 61450...  epsg:32753
#
#                                            buffer_22KM           buffer_area  \
# 350  POLYGON ((137.16433 -4.61718, 137.16558 -5.014... 1936000000.0000000000
#
#      buffer_grouped_id                                buffer_22KM_grouped  \
# 350               1313  POLYGON ((137.16433 -4.61718, 137.16558 -5.014...
#
#                                         buffer_h3_poly grouped_country  \
# 350  POLYGON ((136.76782 -4.82383, 136.76694 -4.828...     {Indonesia}
#
#     grouped_port                                           boundary  \
# 350  {Amamapare}  LINESTRING (137.16433 -4.61718, 137.16558 -5.0...
#
#                                       boundary_polygon  \
# 350  POLYGON ((137.16433 -4.61718, 137.16558 -5.014...
#
#                                          boundary_h3_8
# 350  {88728ad847fffff, 88729dada5fffff, 88729d3647f...

# %% [markdown]
# ### Save

# %%
ports_indo_df.to_pickle(save_path_unique+"ports_indonesia.pkl")

# %% [markdown]
# ### Visualisasi Port Indonesia

# %%
# Generate Peta
m = folium.Map(location=[2, 120], zoom_start=4.2, tiles="CartoDB positron")
# latitude = -6.2088
# longitude = 106.8456
# folium.Marker([latitude, longitude], popup='Ini adalah titik').add_to(m)

# Untuk generate bounding box
for _, r in ports_indo_df.iterrows():
    # Without simplifying the representation of each borough,
    # the map might not be displayed
    sim_geo = gpd.GeoSeries(r["buffer_22KM"]).simplify(tolerance=0.001)
    geo_j = sim_geo.to_json()
    geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "red"})
    folium.Popup(r["Port"]).add_to(geo_j)
    geo_j.add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a0c32961ab0a4350192caf726cf8a56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a0c32961ab0a4350192caf726cf8a56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a0c32961ab0a4350192caf726cf8a56 = L.map(
#                 &quot;map_3a0c32961ab0a4350192caf726cf8a56&quot;,
#                 {
#                     center: [2.0, 120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfa38e2d3fbc449383ee8025da5b687b = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3a0c32961ab0a4350192caf726cf8a56);
#
#
#         function geo_json_f1812998c018157439861388f4ba0916_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_f1812998c018157439861388f4ba0916_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f1812998c018157439861388f4ba0916 = L.geoJson(null, {
#                 onEachFeature: geo_json_f1812998c018157439861388f4ba0916_onEachFeature,
#
#                 style: geo_json_f1812998c018157439861388f4ba0916_styler,
#         });
#
#         function geo_json_f1812998c018157439861388f4ba0916_add (data) {
#             geo_json_f1812998c018157439861388f4ba0916
#                 .addData(data)
#                 .addTo(map_3a0c32961ab0a4350192caf726cf8a56);
#         }
#             geo_json_f1812998c018157439861388f4ba0916_add({&quot;bbox&quot;: [120.86849654258967, -2.9325809418353597, 121.26477239167531, -2.5340983213328743], &quot;features&quot;: [{&quot;bbox&quot;: [120.86849654258967, -2.9325809418353597, 121.26477239167531, -2.5340983213328743], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[121.26477239167531, -2.5346920753252453], [121.26420059474526, -2.9325809418353597], [120.86849654258967, -2.931893836223608], [120.86919847192047, -2.5340983213328743], [121.26477239167531, -2.5346920753252453]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_c6dd79084f9ecfa73ea12b7184fb867a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51df692e07ab30c1ed9489bbc827d302 = $(`&lt;div id=&quot;html_51df692e07ab30c1ed9489bbc827d302&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mangkasa Oil Terminal&lt;/div&gt;`)[0];
#                 popup_c6dd79084f9ecfa73ea12b7184fb867a.setContent(html_51df692e07ab30c1ed9489bbc827d302);
#
#
#
#         geo_json_f1812998c018157439861388f4ba0916.bindPopup(popup_c6dd79084f9ecfa73ea12b7184fb867a)
#         ;
#
#
#
#
#         function geo_json_ae5003acddcb6c46e9358173919012a1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_ae5003acddcb6c46e9358173919012a1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ae5003acddcb6c46e9358173919012a1 = L.geoJson(null, {
#                 onEachFeature: geo_json_ae5003acddcb6c46e9358173919012a1_onEachFeature,
#
#                 style: geo_json_ae5003acddcb6c46e9358173919012a1_styler,
#         });
#
#         function geo_json_ae5003acddcb6c46e9358173919012a1_add (data) {
#             geo_json_ae5003acddcb6c46e9358173919012a1
#                 .addData(data)
#                 .addTo(map_3a0c32961ab0a4350192caf726cf8a56);
#         }
#             geo_json_ae5003acddcb6c46e9358173919012a1_add({&quot;bbox&quot;: [122.3850103412622, -4.165772707147741, 122.7815608306805, -3.767522792322564], &quot;features&quot;: [{&quot;bbox&quot;: [122.3850103412622, -4.165772707147741, 122.7815608306805, -3.767522792322564], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[122.7815608306805, -3.7677129633641706], [122.78145627036598, -4.165772707147741], [122.3850103412622, -4.165562379611707], [122.38530455789513, -3.767522792322564], [122.7815608306805, -3.7677129633641706]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_ee859a096074da639def6540ef5f1bd6 = L.popup({&quot;maxWidth&quot;: &quot;10

# %%
# Untuk generate h3 batas bounding box
for _, r in ports_indo_df_z.iterrows():
    # Without simplifying the representation of each borough,
    # the map might not be displayed
    for element in r['boundary_h3_8']:
        geo_boundary = h3int.h3_to_geo_boundary(element, geo_json=True)
        polygon = Polygon(geo_boundary)
        sim_geo = gpd.GeoSeries(polygon).simplify(tolerance=0.0001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "blue"})
        folium.Popup(r["Port"]).add_to(geo_j)
        geo_j.add_to(m)
    
m

# %% [markdown]
# ### Save csv

# %%
def create_download_link(df, title, filename):
    csv = df.to_csv(index = False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload, title=title, filename=filename)
    return HTML(html)

# %%
ports_indo_bound_df = ports_indo_df['buffer_22KM']

# %%
# Download Data
create_download_link(ports_indo_bound_df, title="ports_indo_bound_df", filename="ports_indo_bound_df.csv")
# Out:
# <a download="ports_indo_bound_df.csv" href="data:text/csv;base64,..." target="_blank">ports_indo_bound_df</a>

# %% [markdown]
# ## Port Luar Negeri

# %%
ports_ln_df = ports_df[ports_df['Country']!="Indonesia"]

# %%
len(ports_ln_df)
# Out:
# 3685

# %% [markdown]
# ### Save

# %%
ports_ln_df.to_pickle(save_path_unique+"ports_luarnegeri.pkl")

# %% [markdown]
# ### Save csv

# %%
ports_ln_bound_df = ports_ln_df['buffer_22KM']

# %%
# Download Data
create_download_link(ports_ln_bound_df, title="ports_ln_bound_df", filename="ports_ln_bound_df.csv")
# Out:
# <a download="ports_ln_bound_df.csv" href="data:text/csv;base64,..." target="_blank">ports_ln_bound_df</a>

# %% [markdown]
# # Non-AOI

# %% [markdown]
# ## Fungsi Generate Non-AOI

# %%
def extract_outer_boundary_and_h3(df, buffer_label):
    # Ekstrak batas poligon buffer_23KM
    df['boundary_outer'] = df[buffer_label].boundary

    # Ubah LineString menjadi Polygon
    df['boundary_outer_polygon'] = df['boundary_outer'].apply(lambda line: Polygon(line))

    # Konversi batas ke H3 indices
    df['boundary_outer_h3'] = poly_to_h3(df['boundary_outer_polygon'], h3_res=8)

    return df

# %%
def wpi_buffer_combined_outer(wpi, utm, buffer_dist_km=23, return_grouped=True):
    buffer_label = f"buffer_{buffer_dist_km}KM"

    print(f"WPI Rows: {wpi.shape[0]:,}")
    
    #aggregate UTM polygons per EPSG
    utm_agg = utm[~utm['ZONE'].isin(['A','B','Y','Z'])][['EPSG','geometry']].dissolve(by=['EPSG'],as_index=False)
    
    #attach UTM info to wpi if wpi polygon is in utm aggregated polygon
    df = gpd.sjoin(wpi[['Country','Port','World Port Index Number','geometry','h3_k_ring']].rename(columns={'World Port Index Number':'port_id'}),
                   utm_agg, predicate='within').drop(columns=['index_right'])
    print(f"WPI with points within UTM Zone: {df.shape[0]:,}")
    
    #generate buffer for each epsg batch
    base_crs = df.crs
    for epsg in df['EPSG'].unique():
        cond = df['EPSG'] == epsg
        df_small = df[cond].copy()
        df_small.to_crs(epsg, inplace=True)
        df_small[buffer_label] = df_small.buffer(buffer_dist_km*1000, cap_style=3)
        df_small.set_geometry(buffer_label, inplace=True)
        df_small["buffer_area"] = df_small.area
        df_small.to_crs(base_crs, inplace=True)

        df.loc[cond,[buffer_label, "buffer_area"]] = df_small[[buffer_label, "buffer_area"]]

    
    # Sisipkan informasi UTM buffer, ini akan memotong buffer menjadi setiap UTM
    df = df.set_geometry(buffer_label).rename(columns={"geometry": "location"})

    # Gabungkan buffer yang tumpang tindih untuk membuat buffer yang dikelompokkan
    df2 = df[[buffer_label]].dissolve().explode(index_parts=True).reset_index(drop=True)
    df2['buffer_grouped_id'] = np.arange(df2.shape[0])
    df2[buffer_label + "_grouped"] = df2[buffer_label]

    print("Menghasilkan indeks H3 untuk buffer yang dikelompokkan..")

    df2['buffer_grouped_h3'] = parallelize_dataframe(df2[buffer_label], poly_to_h3, 100, 4)

    print("Mengkonversi indeks H3 menjadi poligon..")
    df2['buffer_h3_poly'] = parallelize_dataframe(df2['buffer_grouped_h3'], h3_to_poly, 100, 4)

    df4 = df2[['buffer_grouped_h3', 'buffer_grouped_id']].explode('buffer_grouped_h3', ignore_index=True)

    # Sisipkan informasi buffer yang dikelompokkan
    df3 = gpd.sjoin(df.set_geometry("location"),
                    df2.drop(columns=['buffer_grouped_h3']),
                    how='left',
                    predicate='within').drop(columns=['index_right'])
    df3['grouped_country'] = df3['buffer_grouped_id'].map(df3.groupby('buffer_grouped_id')['Country'].agg(set))
    df3['grouped_port'] = df3['buffer_grouped_id'].map(df3.groupby('buffer_grouped_id')["Port"].agg(set))

    df3.set_geometry(buffer_label + "_grouped", inplace=True)
    df3.set_crs(epsg="4326", inplace=True)

    # Ekstrak batas dan konversi ke H3 indices
    df3 = extract_outer_boundary_and_h3(df3, buffer_label)

    print("Selesai")
    return df3, df4

# %% [markdown]
# ## Call Function

# %%
#note, we parallellize conversion of polygons to h3 indices because it takes a while to convert in series, at least 5 mins for 1000K rows
non_aoi_ports_df, outer_box_df = wpi_buffer_combined_outer(wpi, utm, buffer_dist_km=23)
# Out:
# WPI Rows: 3,807
# WPI with points within UTM Zone: 3,807
# Menghasilkan indeks H3 untuk buffer yang dikelompokkan..
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# 100%|██████████| 100/100 [00:06<00:00, 15.64it/s]
# Closing down clientserver connection
# Mengkonversi indeks H3 menjadi poligon..
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# Closing down clientserver connection
# 100%|██████████| 100/100 [00:16<00:00,  5.99it/s]
# Closing down clientserver connection
# Closing down clientserver connection
# /tmp/ipykernel_51/2202810265.py:46: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: None
#
#   df3 = gpd.sjoin(df.set_geometry("location"),
# Selesai

# %%
non_aoi_ports_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 3807 entries, 0 to 3718
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 3807 non-null   object
#  1   Port                    3807 non-null   object
#  2   port_id                 3807 non-null   float64
#  3   location                3807 non-null   geometry
#  4   h3_k_ring               3807 non-null   object
#  5   EPSG                    3807 non-null   object
#  6   buffer_23KM             3807 non-null   geometry
#  7   buffer_area             3807 non-null   float64
#  8   buffer_grouped_id       3807 non-null   int64
#  9   buffer_23KM_grouped     3807 non-null   geometry
#  10  buffer_h3_poly          3807 non-null   geometry
#  11  grouped_country         3807 non-null   object
#  12  grouped_port            3807 non-null   object
#  13  boundary_outer          3807 non-null   geometry
#  14  boundary_outer_polygon  3807 non-null   geometry
#  15  boundary_outer_h3       3807 non-null   object
# dtypes: float64(2), geometry(6), int64(1), object(7)
# memory usage: 505.6+ KB

# %%
# Buang yg sama dg bouding box
non_aoi_ports_df['outer_boundary_h3'] = non_aoi_ports_df.apply(lambda row: 
    np.setdiff1d(row['boundary_outer_h3'], ports_df.at[row.name, 'boundary_h3']).tolist(), axis=1
)

# %% [markdown]
# ## Non-AOI Port Indonesia

# %%
non_aoi_ports_indo_df = non_aoi_ports_df[non_aoi_ports_df['Country']=="Indonesia"]

# %%
non_aoi_ports_indo_df
# Out:
#         Country                   Port          port_id  \
# 1     Indonesia  Mangkasa Oil Terminal 52235.0000000000
# 323   Indonesia                Kendari 52240.0000000000
# 452   Indonesia                Pomalaa 52295.0000000000
# 583   Indonesia                 Kupang 51400.0000000000
# 1626  Indonesia                Maumere 51320.0000000000
# ...         ...                    ...              ...
# 439   Indonesia            Teluk Bayur 50450.0000000000
# 852   Indonesia                Merauke 53130.0000000000
# 1800  Indonesia               Jayapura 53133.0000000000
# 2852  Indonesia              Uleelheue 50600.0000000000
# 2894  Indonesia                 Sabang 50610.0000000000
#
#                          location  \
# 1      POINT (121.06667 -2.73333)
# 323    POINT (122.58333 -3.96667)
# 452    POINT (121.60000 -4.16667)
# 583   POINT (123.58333 -10.16667)
# 1626   POINT (122.21667 -8.61667)
# ...                           ...
# 439    POINT (100.36667 -1.00000)
# 852    POINT (140.38333 -8.48333)
# 1800   POINT (140.71667 -2.53333)
# 2852     POINT (95.28333 5.56667)
# 2894     POINT (95.31667 5.88333)
#
#                                               h3_k_ring        EPSG  \
# 1     [615113569091977215, 615113572587929599, 61511...  epsg:32751
# 323   [615118949972967423, 615118951984136191, 61511...  epsg:32751
# 452   [615113795617947647, 615113793992654847, 61511...  epsg:32751
# 583   [615093508310564863, 615093502180589567, 61509...  epsg:32751
# 1626  [615095841031454719, 615095842321203199, 61509...  epsg:32751
# ...                                                 ...         ...
# 439   [614966846522654719, 614966846197596159, 61496...  epsg:32747
# 852   [615247305584410623, 615247305710239743, 61524...  epsg:32754
# 1800  [614511780697210879, 614511776488226815, 61451...  epsg:32754
# 2852  [614272118818865151, 614272119166992383, 61427...  epsg:32646
# 2894  [614251831320641535, 614251827629654015, 61425...  epsg:32646
#
#                                             buffer_23KM           buffer_area  \
# 1     POLYGON ((121.27378 -2.52566, 121.27318 -2.941... 2116000000.0000000000
# 323   POLYGON ((122.79057 -3.75867, 122.79046 -4.174... 2116000000.0000000000
# 452   POLYGON ((121.80749 -3.95898, 121.80686 -4.375... 2116000000.0000000000
# 583   POLYGON ((123.79278 -9.95822, 123.79381 -10.37... 2116000000.0000000000
# 1626  POLYGON ((122.42600 -8.40900, 122.42537 -8.825... 2116000000.0000000000
# ...                                                 ...                   ...
# 439   POLYGON ((100.57324 -0.79190, 100.57343 -1.207... 2116000000.0000000000
# 852   POLYGON ((140.59251 -8.27557, 140.59207 -8.691... 2116000000.0000000000
# 1800  POLYGON ((140.92357 -2.32528, 140.92355 -2.741... 2116000000.0000000000
# 2852  POLYGON ((95.49171 5.77370, 95.48996 5.35795, ... 2116000000.0000000000
# 2894  POLYGON ((95.52522 6.09029, 95.52334 5.67457, ... 2116000000.0000000000
#
#       buffer_grouped_id                                buffer_23KM_grouped  \
# 1                  1149  POLYGON ((121.27378 -2.52566, 121.27318 -2.941...
# 323                1147  POLYGON ((122.79057 -3.75867, 122.79046 -4.174...
# 452                1145  POLYGON ((121.80749 -3.95898, 121.80686 -4.375...
# 583                1134  POLYGON ((123.79278 -9.95822, 123.79381 -10.37...
# 1626               1138  POLYGON ((122.42600 -8.40900, 122.42537 -8.825...
# ...                 ...                                                ...
# 439                1036  POLYGON ((100.57324 -0.79190, 100.57343 -1.207...
# 852                1386  POLYGON ((140.59251 -8.27557, 140.59207 -8.691...
# 1800               1399  POLYGON ((140.92357 -2.32528, 140.92355 -2.741...
# 2852               1065  POLYGON ((95.10864 5.77524, 95.10984 6.09208, ...
# 2894               1065  POLYGON ((95.10864 5.77524, 95.10984 6.09208, ...
#
#                                          buffer_h3_poly grouped_country  \
# 1     POLYGON ((120.87811 -2.52770, 120.87437 -2.524...     {Indonesia}
# 323   POLYGON ((122.52021 -4.17323, 122.52400 -4.176...     {Indonesia}
# 452   POLYGON ((121.80882 -4.03354, 121.80953 -4.028...     {Indonesia}
# 583   POLYGON ((123.79267 -10.34906, 123.79720 -10.3...     {Indonesia}
# 1626  POLYGON ((122.42692 -8.47326, 122.42764 -8.468...     {Indonesia}
# ...                                                 ...             ...
# 439   POLYGON ((100.21422 -1.20396, 100.21844 -1.206...     {Indonesia}
# 852   POLYGON ((140.17061 -8.53472, 140.16971 -8.539...     {Indonesia}
# 1800  POLYGON ((140.92015 -2.60825, 140.92105 -2.603...     {Indonesia}
# 2852  POLYGON ((95.13169 5.35443, 95.13643 5.35671, ...     {Indonesia}
# 2894  POLYGON ((95.13169 5.35443, 95.13643 5.35671, ...     {Indonesia}
#
#                  grouped_port  \
# 1     {Mangkasa Oil Terminal}
# 323                 {Kendari}
# 452                 {Pomalaa}
# 583                  {Kupang}
# 1626                {Maumere}
# ...                       ...
# 439             {Teluk Bayur}
# 852                 {Merauke}
# 1800               {Jayapura}
# 2852      {Sabang, Uleelheue}
# 2894      {Sabang, Uleelheue}
#
#                                          boundary_outer  \
# 1     LINESTRING (121.27378 -2.52566, 121.27318 -2.9...
# 323   LINESTRING (122.79057 -3.75867, 122.79046 -4.1...
# 452   LINESTRING (121.80749 -3.95898, 121.80686 -4.3...
# 583   LINESTRING (123.79278 -9.95822, 123.79381 -10....
# 1626  LINESTRING (122.42600 -8.40900, 122.42537 -8.8...
# ...                                                 ...
# 439   LINESTRING (100.57324 -0.79190, 100.57343 -1.2...
# 852   LINESTRING (140.59251 -8.27557, 140.59207 -8.6...
# 1800  LINESTRING (140.92357 -2.32528, 140.92355 -2.7...
# 2852  LINESTRING (95.49171 5.77370, 95.48996 5.35795...
# 2894  LINESTRING (95.52522 6.09029, 95.52334 5.67457...
#
#                                  boundary_outer_polygon  \
# 1     POLYGON ((121.27378 -2.52566, 121.27318 -2.941...
# 323   POLYGON ((122.79057 -3.75867, 122.79046 -4.174...
# 452   POLYGON ((121.80749 -3.95898, 121.80686 -4.375...
# 583   POLYGON ((123.79278 -9.95822, 123.79381 -10.37...
# 1626  POLYGON ((122.42600 -8.40900, 122.42537 -8.825...
# ...                                                 ...
# 439   POLYGON ((100.57324 -0.79190, 100.57343 -1.207...
# 852   POLYGON ((140.59251 -8.27557, 140.59207 -8.691...
# 1800  POLYGON ((140.92357 -2.32528, 140.92355 -2.741...
# 2852  POLYGON ((95.49171 5.77370, 95.48996 5.35795, ...
# 2894  POLYGON ((95.52522 6.09029, 95.52334 5.67457, ...
#
#                                       boundary_outer_h3  \
# 1     [615113575230341119, 615113834664820735, 61511...
# 323   [615118946053390335, 615113784345755647, 61511...
# 452   [615113680998105087, 615113680566091775, 61511...
# 583   [615093509294129151, 615093502472093695, 61509...
# 1626  [615095844433035263, 615095842912600063, 61509...
# ...                                                 ...
# 439   [614966838916284415, 614966848114393087, 61496...
# 852   [615247271138689023, 615247307119525887, 61524...
# 1800  [614511780143562751, 614511787756224511, 61451...
# 2852  [614272005560074239, 614272005289541631, 61427...
# 2894  [614272087783112703, 614251827377995775, 61427...
#
#                                       outer_boundary_h3
# 1     [615113568320225279, 615113568347488255, 61511...
# 323   [615113630903435263, 615113749134573567, 61511...
# 452   [615113679945334783, 615113679947431935, 61511...
# 583   [615093503174639615, 615093503178833919, 61509...
# 1626  [615095686125322239, 615095686372786175, 61509...
# ...                                                 ...
# 439   [614966834937987071, 614966834944278527, 61496...
# 852   [615247262085283839, 615247262087380991, 61524...
# 1800  [614509675984977919, 614509675987075071, 61450...
# 2852  [614272005048369151, 614272005052563455, 61427...
# 2894  [614251825949835263, 614251825951932415, 61425...
#
# [122 rows x 17 columns]

# %%
non_aoi_ports_indo_df_x = non_aoi_ports_df[non_aoi_ports_df['Port']=="Tanah Merah"]

# %%
non_aoi_ports_indo_df_y = non_aoi_ports_df[non_aoi_ports_df['Port']=="Merak Mas Terminal"]

# %%
non_aoi_ports_indo_df_z = non_aoi_ports_df[non_aoi_ports_df['Port']=="Tanjung Sekong"]

# %%
non_aoi_ports_indo_df_z
# Out:
#        Country            Port          port_id                    location  \
# 829  Indonesia  Tanjung Sekong 50935.0000000000  POINT (106.00000 -5.91667)
#
#                                              h3_k_ring        EPSG  \
# 829  [614953766640156671, 614953762217263103, 61495...  epsg:32748
#
#                                            buffer_23KM           buffer_area  \
# 829  POLYGON ((106.20731 -5.70823, 106.20822 -6.124... 2116000000.0000000000
#
#      buffer_grouped_id                                buffer_23KM_grouped  \
# 829               1020  POLYGON ((105.79201 -5.75892, 105.79194 -5.708...
#
#                                         buffer_h3_poly grouped_country  \
# 829  POLYGON ((106.18737 -6.13449, 106.18789 -6.129...     {Indonesia}
#
#                                           grouped_port  \
# 829  {Tanjung Sekong, Anyer Lor, Banten, Tanjung Ge...
#
#                                         boundary_outer  \
# 829  LINESTRING (106.20731 -5.70823, 106.20822 -6.1...
#
#                                 boundary_outer_polygon  \
# 829  POLYGON ((106.20731 -5.70823, 106.20822 -6.124...
#
#                                      boundary_outer_h3  \
# 829  [614953806867726335, 614953772390547455, 61495...
#
#                                      outer_boundary_h3
# 829  [614953761883815935, 614953761892204543, 61495...

# %% [markdown]
# ### Save

# %%
non_aoi_ports_indo_df.to_pickle(save_path_unique+"non_aoi_ports_indonesia.pkl")

# %% [markdown]
# ### Visualisasi Non-AOI Port Indonesia

# %%
# Generate Peta
l = folium.Map(location=[2, 120], zoom_start=4.2, tiles="CartoDB positron")
# latitude = -6.2088
# longitude = 106.8456
# folium.Marker([latitude, longitude], popup='Ini adalah titik').add_to(m)

# Untuk generate bounding box
for _, r in ports_indo_df.iterrows():
    # Without simplifying the representation of each borough,
    # the map might not be displayed
    sim_geo = gpd.GeoSeries(r["buffer_22KM"]).simplify(tolerance=0.001)
    geo_j = sim_geo.to_json()
    geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "red"})
    folium.Popup(r["Port"]).add_to(geo_j)
    geo_j.add_to(l)
# Untuk generate h3 tetangga
for _, r in non_aoi_ports_indo_df_z.iterrows():
    # Without simplifying the representation of each borough,
    # the map might not be displayed
    for element in r['outer_boundary_h3']:
        geo_boundary = h3int.h3_to_geo_boundary(element, geo_json=True)
        polygon = Polygon(geo_boundary)
        sim_geo = gpd.GeoSeries(polygon).simplify(tolerance=0.001)
        geo_j = sim_geo.to_json()
        geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "blue"})
        folium.Popup(r["Port"]).add_to(geo_j)
        geo_j.add_to(l)
    
l
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c79e5b039cffe278bad8700ed6f21ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c79e5b039cffe278bad8700ed6f21ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c79e5b039cffe278bad8700ed6f21ff = L.map(
#                 &quot;map_7c79e5b039cffe278bad8700ed6f21ff&quot;,
#                 {
#                     center: [2.0, 120.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2f99a6bcd7bab24ff9745ab615e51ec = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7c79e5b039cffe278bad8700ed6f21ff);
#
#
#         function geo_json_b9ae79baec6c76f8249b55839a875de3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_b9ae79baec6c76f8249b55839a875de3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b9ae79baec6c76f8249b55839a875de3 = L.geoJson(null, {
#                 onEachFeature: geo_json_b9ae79baec6c76f8249b55839a875de3_onEachFeature,
#
#                 style: geo_json_b9ae79baec6c76f8249b55839a875de3_styler,
#         });
#
#         function geo_json_b9ae79baec6c76f8249b55839a875de3_add (data) {
#             geo_json_b9ae79baec6c76f8249b55839a875de3
#                 .addData(data)
#                 .addTo(map_7c79e5b039cffe278bad8700ed6f21ff);
#         }
#             geo_json_b9ae79baec6c76f8249b55839a875de3_add({&quot;bbox&quot;: [120.86849654258967, -2.9325809418353597, 121.26477239167531, -2.5340983213328743], &quot;features&quot;: [{&quot;bbox&quot;: [120.86849654258967, -2.9325809418353597, 121.26477239167531, -2.5340983213328743], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[121.26477239167531, -2.5346920753252453], [121.26420059474526, -2.9325809418353597], [120.86849654258967, -2.931893836223608], [120.86919847192047, -2.5340983213328743], [121.26477239167531, -2.5346920753252453]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_d1fa6b084eeee13be01b2453631ce359 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c92781c2b02f6d5423d94bbb03fc26c = $(`&lt;div id=&quot;html_7c92781c2b02f6d5423d94bbb03fc26c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mangkasa Oil Terminal&lt;/div&gt;`)[0];
#                 popup_d1fa6b084eeee13be01b2453631ce359.setContent(html_7c92781c2b02f6d5423d94bbb03fc26c);
#
#
#
#         geo_json_b9ae79baec6c76f8249b55839a875de3.bindPopup(popup_d1fa6b084eeee13be01b2453631ce359)
#         ;
#
#
#
#
#         function geo_json_ca2eb3bc8e8393313de373dd3ed3ca23_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_ca2eb3bc8e8393313de373dd3ed3ca23_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ca2eb3bc8e8393313de373dd3ed3ca23 = L.geoJson(null, {
#                 onEachFeature: geo_json_ca2eb3bc8e8393313de373dd3ed3ca23_onEachFeature,
#
#                 style: geo_json_ca2eb3bc8e8393313de373dd3ed3ca23_styler,
#         });
#
#         function geo_json_ca2eb3bc8e8393313de373dd3ed3ca23_add (data) {
#             geo_json_ca2eb3bc8e8393313de373dd3ed3ca23
#                 .addData(data)
#                 .addTo(map_7c79e5b039cffe278bad8700ed6f21ff);
#         }
#             geo_json_ca2eb3bc8e8393313de373dd3ed3ca23_add({&quot;bbox&quot;: [122.3850103412622, -4.165772707147741, 122.7815608306805, -3.767522792322564], &quot;features&quot;: [{&quot;bbox&quot;: [122.3850103412622, -4.165772707147741, 122.7815608306805, -3.767522792322564], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[122.7815608306805, -3.7677129633641706], [122.78145627036598, -4.165772707147741], [122.3850103412622, -4.165562379611707], [122.38530455789513, -3.767522792322564], [122.7815608306805, -3.7677129633641706]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_493e663f0a0ea82d98b1538997ba60ab = L.popup({&quot;maxWidth&quot;: &quot;10

# %% [markdown]
# ## Non-AOI Port Luar Negeri

# %%
non_aoi_ports_ln_df = non_aoi_ports_df[non_aoi_ports_df['Country']!="Indonesia"]

# %% [markdown]
# ### Save

# %%
non_aoi_ports_ln_df.to_pickle(save_path_unique+"non_aoi_ports_luarnegeri.pkl")

# %% [markdown]
# ## Save Sparkdataframe

# %% [markdown]
# ### AOI Port Indonesia

# %%
# Select Kolom
selected_columns = ["Port","boundary_h3_8","boundary_h3_12"]
ports_indo_df_select = ports_indo_df[selected_columns]

# %%
# Mengubah tipe data kolom boundary_h3 dari object ke array long
ports_indo_df_select.loc[:, 'boundary_h3_8'] = ports_indo_df_select['boundary_h3_8'].apply(lambda arr: [int(x) for x in arr])
# Out:
# /tmp/ipykernel_51/1092415246.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ports_indo_df_select.loc[:, 'boundary_h3'] = ports_indo_df_select['boundary_h3'].apply(lambda arr: [int(x) for x in arr])

# %%
# Mengubah tipe data kolom boundary_h3 dari object ke array long
ports_indo_df_select.loc[:, 'boundary_h3_12'] = ports_indo_df_select['boundary_h3_12'].apply(lambda arr: [int(x) for x in arr])

# %%
# Mendefinisikan skema Spark
schema = StructType([
    StructField("Port", StringType(), True),
    StructField("boundary_h3_8", ArrayType(LongType()), True)
    StructField("boundary_h3_12", ArrayType(LongType()), True)
])

# Membuat DataFrame Spark
ports_indo_df_select_spark = spark.createDataFrame(ports_indo_df_select, schema=schema)
# Out:
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.

# %%
# cek
ports_indo_df_select_spark.show(5)
# Out:
# Error while sending or receiving.
# Traceback (most recent call last):
#   File "/opt/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 503, in send_command
#     self.socket.sendall(command.encode("utf-8"))
# ConnectionResetError: [Errno 104] Connection reset by peer
# Closing down clientserver connection
# Exception while sending command.
# Traceback (most recent call last):
#   File "/opt/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 503, in send_command
#     self.socket.sendall(command.encode("utf-8"))
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/opt/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 506, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending
# Closing down clientserver connection
# +--------------------+--------------------+
# |                Port|         boundary_h3|
# +--------------------+--------------------+
# |Mangkasa Oil Term...|[6151135725355007...|
# |             Kendari|[6151189460366131...|
# |             Pomalaa|[6151137935040184...|
# |              Kupang|[6150935022560870...|
# |             Maumere|[6150958612039598...|
# +--------------------+--------------------+
# only showing top 5 rows

# %%
# cek
ports_indo_df_select_spark.printSchema()
# Out:
# root
#  |-- Port: string (nullable = true)
#  |-- boundary_h3: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
# Save
ports_indo_df_select_spark.write.option("header", True).mode("overwrite").parquet(save_path_unique + "ports_indonesia.parquet")

# %% [markdown]
# ### AOI Port LN

# %%
# Select Kolom
selected_columns = ["Port","Country","boundary_h3_8","boundary_h3_12"]
ports_ln_df_select = ports_ln_df[selected_columns]

# %%
# Mengubah tipe data kolom boundary_h3 dari object ke array long
ports_ln_df_select.loc[:, 'boundary_h3_8'] = ports_ln_df_select['boundary_h3_8'].apply(lambda arr: [int(x) for x in arr])
# Out:
# /tmp/ipykernel_51/828118847.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ports_ln_df_select.loc[:, 'boundary_h3'] = ports_ln_df_select['boundary_h3'].apply(lambda arr: [int(x) for x in arr])

# %%
# Mengubah tipe data kolom boundary_h3 dari object ke array long
ports_ln_df_select.loc[:, 'boundary_h3_12'] = ports_ln_df_select['boundary_h3_12'].apply(lambda arr: [int(x) for x in arr])

# %%
# Mendefinisikan skema Spark
schema = StructType([
    StructField("Port", StringType(), True),
    StructField("Country", StringType(), True),
    StructField("boundary_h3_8", ArrayType(LongType()), True)
    StructField("boundary_h3_12", ArrayType(LongType()), True)
])

# Membuat DataFrame Spark
ports_ln_df_select_spark = spark.createDataFrame(ports_ln_df_select, schema=schema)
# Out:
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.

# %%
# cek
ports_ln_df_select_spark.show(5)
# Out:
# +---------+-------------+--------------------+
# |     Port|      Country|         boundary_h3|
# +---------+-------------+--------------------+
# |   Maurer|United States|[6132295481771950...|
# |  Bayboro|United States|[6132431155888127...|
# | Chaumont|United States|[6132558002651135...|
# |Grasselli|United States|[6132295510293217...|
# | Carillon|       Canada|[6132549240498421...|
# +---------+-------------+--------------------+
# only showing top 5 rows

# %%
# cek
ports_ln_df_select_spark.printSchema()
# Out:
# root
#  |-- Port: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- boundary_h3: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
# Save
ports_ln_df_select_spark.write.option("header", True).mode("overwrite").parquet(save_path_unique + "ports_luarnegeri.parquet")

# %% [markdown]
# ### Non-AOI Port Indonesia

# %%
# Select Kolom
selected_columns = ["Port","outer_boundary_h3"]
non_aoi_ports_indo_df_select = non_aoi_ports_indo_df[selected_columns]

# %%
# ubah ke Sparkdataframe
non_aoi_ports_indo_df_select = spark.createDataFrame(non_aoi_ports_indo_df_select)
# Out:
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:474: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.

# %%
# cek
non_aoi_ports_indo_df_select.printSchema()
# Out:
# root
#  |-- Port: string (nullable = true)
#  |-- outer_boundary_h3: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
# Save
non_aoi_ports_indo_df_select.write.option("header", True).mode("overwrite").parquet(save_path_unique + "non_aoi_ports_indonesia.parquet")

# %% [markdown]
# ### Non-AOI Port LN

# %%
# Select Kolom
selected_columns = ["Port","Country","outer_boundary_h3"]
non_aoi_ports_ln_df_select = non_aoi_ports_ln_df[selected_columns]

# %%
# ubah ke Sparkdataframe
non_aoi_ports_ln_df_select = spark.createDataFrame(non_aoi_ports_ln_df_select)
# Out:
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:474: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.

# %%
# cek
non_aoi_ports_ln_df_select.printSchema()
# Out:
# root
#  |-- Port: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- outer_boundary_h3: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
# Save
non_aoi_ports_ln_df_select.write.option("header", True).mode("overwrite").parquet(save_path_unique + "non_aoi_ports_luarnegeri.parquet")

# %% [markdown]
# ### Pelabuhan Merak

# %%
# Select Kolom
selected_columns = ["Port","boundary_h3"]
ports_indo_df_z_select = ports_indo_df_z[selected_columns]

# %%
# Mengubah tipe data kolom boundary_h3 dari object ke array long
ports_indo_df_z_select.loc[:, 'boundary_h3'] = ports_indo_df_z_select['boundary_h3'].apply(lambda arr: [int(x) for x in arr])
# Out:
# /tmp/ipykernel_51/4085963394.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ports_indo_df_z_select.loc[:, 'boundary_h3'] = ports_indo_df_z_select['boundary_h3'].apply(lambda arr: [int(x) for x in arr])

# %%
# Mendefinisikan skema Spark
schema = StructType([
    StructField("Port", StringType(), True),
    StructField("boundary_h3", ArrayType(LongType()), True)
])

# Membuat DataFrame Spark
ports_indo_df_z_select_spark = spark.createDataFrame(ports_indo_df_z_select, schema=schema)

# %%
# Save
ports_indo_df_z_select_spark.write.option("header", True).mode("overwrite").parquet(save_path_unique + "port_merak.parquet")

# %%
# Select Kolom
selected_columns = ["Port","outer_boundary_h3"]
non_aoi_ports_indo_df_z_select = non_aoi_ports_indo_df_z[selected_columns]

# %%
# ubah ke Sparkdataframe
non_aoi_ports_indo_df_z_select = spark.createDataFrame(non_aoi_ports_indo_df_z_select)
# Out:
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:474: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.

# %%
# Save
non_aoi_ports_indo_df_z_select.write.option("header", True).mode("overwrite").parquet(save_path_unique + "non_aoi_port_merak.parquet")

# %% [markdown]
# ### Pelabuhan Amamapare

# %%
# Select Kolom
selected_columns = ["Port","boundary_h3_8"]
ports_indo_df_w_select = ports_indo_df_w[selected_columns]

# %%
# Mengubah tipe data kolom boundary_h3 dari object ke array long
ports_indo_df_w_select.loc[:, 'boundary_h3_8'] = ports_indo_df_w_select['boundary_h3_8'].apply(lambda arr: [int(x) for x in arr])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 # Mengubah tipe data kolom boundary_h3 dari object ke array long
# ----> 2 ports_indo_df_w_select.loc[:, 'boundary_h3_8'] = ports_indo_df_w_select['boundary_h3_8'].apply(lambda arr: [int(x) for x in arr])
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File /opt/conda/lib/python3.8/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/conda/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[49], line 2, in <lambda>(arr)
#       1 # Mengubah tipe data kolom boundary_h3 dari object ke array long
# ----> 2 ports_indo_df_w_select.loc[:, 'boundary_h3_8'] = ports_indo_df_w_select['boundary_h3_8'].apply(lambda arr: [int(x) for x in arr])
#
# Cell In[49], line 2, in <listcomp>(.0)
#       1 # Mengubah tipe data kolom boundary_h3 dari object ke array long
# ----> 2 ports_indo_df_w_select.loc[:, 'boundary_h3_8'] = ports_indo_df_w_select['boundary_h3_8'].apply(lambda arr: [int(x) for x in arr])
#
# ValueError: invalid literal for int() with base 10: '88728ad847fffff'

# %%
# Mendefinisikan skema Spark
schema = StructType([
    StructField("Port", StringType(), True),
    StructField("boundary_h3", ArrayType(LongType()), True)
])

# Membuat DataFrame Spark
ports_indo_df_w_select_spark = spark.createDataFrame(ports_indo_df_w_select, schema=schema)

# %%
# Save
ports_indo_df_w_select_spark.write.option("header", True).mode("overwrite").parquet(save_path_unique + "port_amamapare.parquet")

# %%
# Select Kolom
selected_columns = ["Port","outer_boundary_h3"]
non_aoi_ports_indo_df_w_select = non_aoi_ports_indo_df_w[selected_columns]

# %%
# ubah ke Sparkdataframe
non_aoi_ports_indo_df_w_select = spark.createDataFrame(non_aoi_ports_indo_df_w_select)

# %%
# Save
non_aoi_ports_indo_df_w_select.write.option("header", True).mode("overwrite").parquet(save_path_unique + "non_aoi_port_amamapare.parquet")
